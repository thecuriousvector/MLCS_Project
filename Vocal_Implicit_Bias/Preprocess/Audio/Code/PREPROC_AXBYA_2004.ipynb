# %%
import pandas as pd
import numpy as np
import os.path
#make sure gender_word.py is under the same folder
from nltk.tag.perceptron import PerceptronTagger
import nltk
#nltk.download_shell()
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/richadeshmukh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
gender_dictionary = {}
male_list = open("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/text/male_list.txt", 'r')
female_list = open("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/text/female_list.txt", 'r')

for word in male_list:
    male_key = word.rstrip('\n')
    gender_dictionary[male_key] = 1

for word in female_list:
    female_key = word.rstrip('\n')
    gender_dictionary[female_key] = -1

male_list.close()
female_list.close()

def G(word):
    '''
    A function that accepts a string as an argument and returns the gender associated with 
    the string.

    Args
    ----
    word - a str

    Returns
    -------
    1  - if the word is in gender_dictionary and gender_dictionary[word] = 1
    -1 - if the word is in gender_dictionary and gender_dictioanry[word] = -1
    0  - if the word is not in gender_dictionary
    '''
    return gender_dictionary.get(word, 0)

# %%
def get_start(path):

    print "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2004.csv"
    whole_list = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2004.csv")
    
    #start point & end point
    index = 0
    row_num = whole_list.shape[0]
    tmp = 0

    #log file
    if os.path.isfile('log_2004.bin'):
        with open("log_2004.bin","r") as log_file:
            log_content = log_file.readlines()[0].split(" ")
            if len(log_content)>0:
                index = int(log_content[-2])
                tmp = whole_list["TextGrid"][index]
                print ("Start from ",tmp)
            else:
                print ("log file is empty")
    else:
        print ("File doesn't exist.")
        print ("Start from begining")


    with open("log_2004.bin","a+") as log_file: 
        #go through every row in index file and record log
        counter1=1
        while(index < row_num):
            print("Counter1 is "+str(counter1)+"\n")
            if whole_list["useable"][index]==1:
                if tmp != whole_list["TextGrid"][index]:
                    log_file.write(str(index)+" ")
                    log_file.flush()
                    tmp = whole_list["TextGrid"][index]
                    year = whole_list["Year"][index]
                    get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
            index += 1

# %%
def get_audio_feature(path,year,filename,whole_list):
    # for ABA format
    # path indicate the root direction for the whole data
    # filename represents .csv file for aba 
    # return an n*23 matrix contains speaker infomation, audio features and classify
    
    aba_table_info = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/axbya_table_info.csv")
    filepath = "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/"+str(filename)+".csv"
    #check exist
    if os.path.isfile(filepath)==False:
        return
    else:
        print "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/"+str(filename)+".csv"
    feature_list = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/"+str(filename)+".csv")
    row_num = feature_list.shape[0]
    #illegal file
    if row_num == 0:
        return

    df = pd.DataFrame()
    index = 0.0
    number_m = 0.0;
    gender_word_male = {};
    number_w = 0.0;
    gender_word_female = {};
    speaker_id_map = {};
    vowel_id = {};
    pretrain = PerceptronTagger()
    counter2=0;
    while (index < row_num):
        counter2+=1
        if(counter2%1000 == 0):
            print("Completed reading rows"+str(counter2))
        text = feature_list["word"][index]
        identity_for_text = pretrain.tag([text])
        if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):#filter
            # record 
            classify = G(text.lower());
            if classify == 1:
                value = gender_word_male.get(text, -1)
                if value != -1:
                    gender_word_male[text] += 1
                else: 
                    gender_word_male[text] = 1
                number_m += 1
            if classify == -1:
                value = gender_word_female.get(text, -1)
                if value!=-1:
                    gender_word_female[text] += 1
                else:
                    gender_word_female[text] = 1
                number_w += 1

            vowel = feature_list["vowel"][index]#added feature
            value = vowel_id.get(vowel, -1)
            if value == -1:
                vowel_id[vowel] = 1

            #decide who do the speach 
            speak_a_id = feature_list["speakerA1_id"][index]
            speak_b_id = feature_list["speakerB_id"][index]
            speak_x_id = feature_list["speakerY_id"][index]
            speak_y_id = feature_list["speakerX_id"][index]
            tier_num = feature_list["tiernum"][index]
            dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
            speaker_pattern = []
            if len(dt_row) > 0:
                speaker = whole_list["TierName"][dt_row].tolist()
                speakers = speaker[0].split(" ")
                for s in speakers:
                    s_tmp = list(s)
                    s_tmp[0] = s_tmp[0].upper()
                    s = "".join(s_tmp)
                    speaker_pattern.append(s)
            
            pattern = "|".join(speaker_pattern)

            dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&((aba_table_info["speakerA"].str.contains(pattern,na=False))|
                (aba_table_info["speakerB"].str.contains(pattern,na=False))|(aba_table_info["speakerX"].str.contains(pattern,na=False))|
                (aba_table_info["speakerY"].str.contains(pattern,na=False)))].index
            dt_row_2 = dt_row_tmp.tolist()
            if len(dt_row_2) != 0:
                speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
                value = speaker_id_map.get(speaker_id, -1)
                if value == -1:
                    speaker_id_map[speaker_id] = 1
                
                text_feature_f1 = feature_list["F1"][index]
                text_feature_f2 = feature_list["F2"][index]
                text_feature_f3 = feature_list["F3"][index]
                text_feature_B1 = feature_list["B1"][index]
                text_feature_B2 = feature_list["B2"][index]
                text_feature_B3 = feature_list["B3"][index]
                text_feature_t = feature_list["t"][index]
                text_feature_beg = feature_list["beg"][index]
                text_feature_end = feature_list["end"][index]
                text_feature_dur = feature_list["dur"][index]
                text_feature_F120 = feature_list["F1@20%"][index]
                text_feature_F220 = feature_list["F2@20%"][index]
                text_feature_F135 = feature_list["F1@35%"][index]
                text_feature_F235 = feature_list["F2@35%"][index]
                text_feature_F150 = feature_list["F1@50%"][index]
                text_feature_F250 = feature_list["F2@50%"][index]
                text_feature_F160 = feature_list["F1@65%"][index]
                text_feature_F260 = feature_list["F2@65%"][index]
                text_feature_F180 = feature_list["F1@80%"][index]
                text_feature_F280 = feature_list["F2@80%"][index]
                tmp_data = np.array([speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
                    text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
                    text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
                    text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify]).reshape(1,22)
                test_data_tmp = pd.DataFrame(tmp_data,columns=['speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
                    'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify'])
                test_data_tmp['docket_id'] = filename
                test_data_tmp['identity'] = identity_for_text[0][1]
                test_data_tmp['text'] = text
                test_data_tmp['vowel'] = vowel
                df = df.append(test_data_tmp,ignore_index=True)
        index += 1

    # extract mean
    mean_df = pd.DataFrame()
    for key in speaker_id_map:
        for key_2 in vowel_id:
            df_tmp = df[(df['speaker_id']==key)&(df['vowel']==key_2)].mean()
            df_tmp['speaker_id'] = key;
            df_tmp['vowel'] = key_2
            mean_df = mean_df.append(df_tmp,ignore_index=True)
    if df.shape[0]!=0:

        new_colom_f1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f3 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B3 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        for i_new in range(df.shape[0]):
            mean_df_id = mean_df[(mean_df['speaker_id']==float(df['speaker_id'][i_new]))&(mean_df['vowel']==df['vowel'][i_new])]
            new_colom_f1[i_new] = df['f1'][i_new]- mean_df_id['f1']
            new_colom_f2[i_new] = df['f2'][i_new]- mean_df_id['f2']
            new_colom_f3[i_new] = df['f3'][i_new]- mean_df_id['f3']
            new_colom_B1[i_new] = df['B1'][i_new]- mean_df_id['B1']
            new_colom_B2[i_new] = df['B2'][i_new]- mean_df_id['B2']
            new_colom_B3[i_new] = df['B3'][i_new]- mean_df_id['B3']

            new_colom_f1_20[i_new] = df['f1@20%'][i_new]- mean_df_id['f1@20%']
            new_colom_f1_35[i_new] = df['f1@35%'][i_new]- mean_df_id['f1@35%']
            new_colom_f1_50[i_new] = df['f1@50%'][i_new]- mean_df_id['f1@50%']
            new_colom_f1_60[i_new] = df['f1@60%'][i_new]- mean_df_id['f1@60%']
            new_colom_f1_80[i_new] = df['f1@80%'][i_new]- mean_df_id['f1@80%']
            new_colom_f2_20[i_new] = df['f2@20%'][i_new]- mean_df_id['f2@20%']
            new_colom_f2_35[i_new] = df['f2@35%'][i_new]- mean_df_id['f2@35%']
            new_colom_f2_50[i_new] = df['f2@50%'][i_new]- mean_df_id['f2@50%']
            new_colom_f2_60[i_new] = df['f2@60%'][i_new]- mean_df_id['f2@60%']
            new_colom_f2_80[i_new] = df['f2@80%'][i_new]- mean_df_id['f2@80%']

        # add new column
        df['f1_c'] = new_colom_f1
        df['f2_c'] = new_colom_f2
        df['f3_c'] = new_colom_f3
        df['B1_c'] = new_colom_B1
        df['B2_c'] = new_colom_B2
        df['B3_c'] = new_colom_B3

        df['f1@20%_c'] = new_colom_f1_20
        df['f1@35%_c'] = new_colom_f1_35
        df['f1@50%_c'] = new_colom_f1_50
        df['f1@60%_c'] = new_colom_f1_60
        df['f1@80%_c'] = new_colom_f1_80
        df['f2@20%_c'] = new_colom_f2_20
        df['f2@35%_c'] = new_colom_f2_35
        df['f2@50%_c'] = new_colom_f2_50
        df['f2@60%_c'] = new_colom_f2_60
        df['f2@80%_c'] = new_colom_f2_80
        # save or add these column into the audio_feature.csv file
        if not os.path.isfile('audio_feature_axbya_2004.csv'):
            df.to_csv('audio_feature_axbya_2004.csv',header ='column_names',index = False)
        else:
            df.to_csv('audio_feature_axbya_2004.csv',mode = 'a',header=False,index = False)
    
    print "total number of words: ",row_num
    print "For male: ",number_m,gender_word_male
    print "percentage for label as male:",number_m/row_num
    print "For female: ",number_w,gender_word_female
    print "percentage for label as female:",number_w/row_num
    print ""
    return

# %%
data_dir = '/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/'
output_dir = '/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/'
get_start(data_dir)
# Out:
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2004.csv
# ('Start from ', '2004_02_1028.TextGrid')
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_02_1192.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9056
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_02_1472.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9925
# For male:  3.0 {'HE': 3}
# percentage for label as male: 0.000302267002519
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_02_1672.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7866
# For male:  18.0 {'HIM': 3, 'HE': 15}
# percentage for label as male: 0.00228832951945
# For female:  8.0 {'WOMAN': 4, 'SHE': 4}
# percentage for label as female: 0.00101703534198
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_10198.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9779
# For male:  111.0 {'HIM': 20, 'HE': 91}
# percentage for label as male: 0.0113508538705
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1039.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9729
# For male:  55.0 {'GENTLEMEN': 6, 'FOREMAN': 2, 'HIM': 8, 'HE': 39}
# percentage for label as male: 0.00565320176791
# For female:  4.0 {'LADIES': 4}
# percentage for label as female: 0.000411141946757
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1116.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8963
# For male:  12.0 {'COUNT': 6, 'HE': 6}
# percentage for label as male: 0.00133883744282
# For female:  2.0 {'SHE': 2}
# percentage for label as female: 0.000223139573803
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1160.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10366
# For male:  21.0 {'MASTER': 4, 'HIM': 4, 'HE': 13}
# percentage for label as male: 0.00202585375265
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1164.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9851
# For male:  4.0 {'COUNT': 1, 'HE': 1, 'HIM': 1, 'MAN': 1}
# percentage for label as male: 0.000406050147193
# For female:  2.0 {'DAUGHTER': 2}
# percentage for label as female: 0.000203025073597
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1237.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5379
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1293.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# total number of words:  4408
# For male:  1.0 {'MAN': 1}
# percentage for label as male: 0.000226860254083
# For female:  6.0 {'COW': 6}
# percentage for label as female: 0.0013611615245
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1388.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7878
# For male:  3.0 {'MASTER': 2, 'HE': 1}
# percentage for label as male: 0.0003808073115
# For female:  3.0 {'QUEEN': 3}
# percentage for label as female: 0.0003808073115
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1395.csv
# /Users/richadeshmukh/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8199
# For male:  9.0 {'HIM': 3, 'HE': 6}
# percentage for label as male: 0.00109769484083
# For female:  1.0 {'DOE': 1}
# percentage for label as female: 0.000121966093426
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1407.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11686
# For male:  2.0 {'HE': 2}
# percentage for label as male: 0.000171144959781
# For female:  5.0 {'SHE': 5}
# percentage for label as female: 0.000427862399452
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1454.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9649
# For male:  9.0 {'HIM': 2, 'HE': 7}
# percentage for label as male: 0.000932739143953
# For female:  8.0 {'WOMAN': 4, 'SHE': 4}
# percentage for label as female: 0.000829101461291
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1488.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7057
# For male:  49.0 {'MAYOR': 2, 'MAN': 1, 'HIM': 7, 'HE': 39}
# percentage for label as male: 0.00694346039394
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1500.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11672
# For male:  33.0 {'KING': 3, 'STEER': 2, 'LORD': 2, 'MAN': 1, 'HIM': 1, 'FRATERNAL': 18, 'HE': 6}
# percentage for label as male: 0.00282727895819
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1566.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7599
# For male:  4.0 {'HIM': 2, 'HE': 2}
# percentage for label as male: 0.000526385050665
# For female:  6.0 {'DAUGHTER': 6}
# percentage for label as female: 0.000789577575997
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1601.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8430
# For male:  8.0 {'COUNT': 4, 'HIM': 1, 'HE': 3}
# percentage for label as male: 0.000948991696323
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1693.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# total number of words:  4758
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_1696.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# total number of words:  3163
# For male:  15.0 {'HE': 15}
# percentage for label as male: 0.00474233322795
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_184.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12426
# For male:  72.0 {'SPOKESMAN': 2, 'MASTER': 6, 'HIM': 5, 'HE': 59}
# percentage for label as male: 0.00579430226944
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 8.04764204088e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_287.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8074
# For male:  40.0 {'COUNT': 2, 'HIM': 3, 'HE': 35}
# percentage for label as male: 0.0049541738915
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000123854347288
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_377.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# total number of words:  13280
# For male:  18.0 {'HIM': 2, 'HE': 16}
# percentage for label as male: 0.00135542168675
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_388.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8006
# For male:  12.0 {'HIM': 2, 'HE': 10}
# percentage for label as male: 0.00149887584312
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_407.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9625
# For male:  21.0 {'MAN': 3, 'HIM': 5, 'HE': 13}
# percentage for label as male: 0.00218181818182
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_409.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# total number of words:  6527
# For male:  9.0 {'HE': 9}
# percentage for label as male: 0.00137888769726
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_583.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7226
# For male:  31.0 {'HE': 22, 'HIM': 5, 'ACTOR': 2, 'MAN': 2}
# percentage for label as male: 0.00429006365901
# For female:  1.0 {'DOE': 1}
# percentage for label as female: 0.000138389150291
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_633.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9630
# For male:  8.0 {'HE': 8}
# percentage for label as male: 0.000830737279335
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_636.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10572
# For male:  32.0 {'HE': 19, 'HIM': 7, 'BROTHERHOOD': 6}
# percentage for label as male: 0.00302686341279
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_674.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7403
# For male:  34.0 {'HIM': 5, 'HE': 29}
# percentage for label as male: 0.00459273267594
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_710.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11819
# For male:  96.0 {'COUNT': 1, 'SIR': 1, 'HART': 2, 'POLICEMAN': 21, 'MAN': 1, 'HIM': 11, 'HE': 59}
# percentage for label as male: 0.00812251459514
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_725.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5584
# For male:  5.0 {'HIM': 3, 'HE': 2}
# percentage for label as male: 0.000895415472779
# For female:  1.0 {'GOOSE': 1}
# percentage for label as female: 0.000179083094556
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_750.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10213
# For male:  33.0 {'COUNT': 7, 'HIM': 2, 'HE': 24}
# percentage for label as male: 0.00323117595222
# For female:  13.0 {'SISTER': 6, 'WOMAN': 4, 'SHE': 2, 'WIFE': 1}
# percentage for label as female: 0.00127288749633
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_814.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5400
# For male:  16.0 {'MAN': 2, 'MASTER': 6, 'HIM': 2, 'HE': 6}
# percentage for label as male: 0.00296296296296
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_855.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8012
# For male:  6.0 {'HE': 6}
# percentage for label as male: 0.000748876684973
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_878.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9261
# For male:  66.0 {'MAN': 1, 'HIM': 21, 'HE': 44}
# percentage for label as male: 0.00712666018788
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_892.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7726
# For male:  36.0 {'COUNT': 1, 'EARL': 1, 'ACTOR': 4, 'HIM': 1, 'HUSBAND': 7, 'HE': 22}
# percentage for label as male: 0.00465959099146
# For female:  3.0 {'WIFE': 3}
# percentage for label as female: 0.000388299249288
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9046.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7481
# For male:  55.0 {'HIM': 5, 'HE': 50}
# percentage for label as male: 0.00735195829435
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9168.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# total number of words:  14011
# For male:  84.0 {'HIM': 3, 'HE': 81}
# percentage for label as male: 0.00599528941546
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000214117479124
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_923.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10189
# For male:  151.0 {'POLICEMAN': 18, 'HE': 48, 'DOG': 76, 'HIM': 9}
# percentage for label as male: 0.0148199038178
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 9.81450583963e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_931.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5295
# For male:  36.0 {'HIM': 11, 'HE': 25}
# percentage for label as male: 0.00679886685552
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000188857412653
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9560.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12436
# For male:  156.0 {'SIR': 27, 'MAN': 3, 'HIM': 29, 'HE': 97}
# percentage for label as male: 0.0125442264394
# For female:  1.0 {'WIFE': 1}
# percentage for label as female: 8.04117079447e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9627.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# total number of words:  13634
# For male:  144.0 {'MAN': 1, 'HIM': 6, 'HE': 137}
# percentage for label as male: 0.0105618307173
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9659.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7999
# For male:  41.0 {'HE': 34, 'HIM': 5, 'MAN': 2}
# percentage for label as male: 0.00512564070509
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000125015626953
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9685.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9158
# For male:  56.0 {'COUNT': 5, 'DOG': 1, 'HIM': 6, 'HE': 44}
# percentage for label as male: 0.00611487224285
# For female:  2.0 {'LADY': 2}
# percentage for label as female: 0.000218388294387
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_03_9877.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10984
# For male:  13.0 {'BROTHER': 4, 'HIM': 1, 'HE': 8}
# percentage for label as male: 0.0011835396941
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_104.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# total number of words:  19832
# For male:  85.0 {'COUNT': 3, 'HOST': 3, 'HIM': 8, 'ACTOR': 4, 'HE': 67}
# percentage for label as male: 0.00428600242033
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_108.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9451
# For male:  6.0 {'BULLOCK': 6}
# percentage for label as male: 0.000634853454661
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_163.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# total number of words:  6922
# For male:  2.0 {'LANDLORD': 2}
# percentage for label as male: 0.000288933834152
# For female:  11.0 {'GRANDMOTHER': 9, 'BELLE': 2}
# percentage for label as female: 0.00158913608784
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_277.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8678
# For male:  2.0 {'BROTHER': 2}
# percentage for label as male: 0.000230467849735
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_278.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8445
# For male:  16.0 {'POLICEMAN': 3, 'FATHER': 2, 'HIM': 6, 'HE': 5}
# percentage for label as male: 0.00189461219657
# For female:  48.0 {'SHE': 48}
# percentage for label as female: 0.0056838365897
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_340.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9392
# For male:  5.0 {'HE': 5}
# percentage for label as male: 0.000532367972743
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_368.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8262
# For male:  33.0 {'MAN': 1, 'HIM': 11, 'ACTOR': 2, 'HE': 19}
# percentage for label as male: 0.0039941902687
# For female:  6.0 {'WOMAN': 4, 'WIFE': 2}
# percentage for label as female: 0.000726216412491
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_37.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9206
# For male:  9.0 {'HIM': 1, 'CHAIRMAN': 2, 'HE': 6}
# percentage for label as male: 0.000977623289159
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_480.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9374
# For male:  5.0 {'HE': 5}
# percentage for label as male: 0.000533390228291
# For female:  4.0 {'MOTHER': 4}
# percentage for label as female: 0.000426712182633
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_495.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9032
# For male:  59.0 {'HIM': 18, 'HE': 41}
# percentage for label as male: 0.00653232949513
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_514.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# total number of words:  6593
# For male:  11.0 {'COUNT': 3, 'MAN': 1, 'HE': 7}
# percentage for label as male: 0.00166843622023
# For female:  5.0 {'SHE': 5}
# percentage for label as female: 0.000758380100106
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_5286.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11311
# For male:  59.0 {'HIM': 11, 'HE': 48}
# percentage for label as male: 0.00521616125895
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_5293.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# total number of words:  4843
# For male:  61.0 {'MAN': 6, 'HIM': 14, 'HE': 41}
# percentage for label as male: 0.0125954986579
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_5462.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7343
# For male:  93.0 {'NEPHEW': 4, 'MAN': 3, 'FATHER': 2, 'HIM': 11, 'HE': 73}
# percentage for label as male: 0.0126651232466
# For female:  12.0 {'GRANDMOTHER': 3, 'WOMAN': 2, 'SHE': 5, 'NIECE': 2}
# percentage for label as female: 0.00163420945118
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_563.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5666
# For male:  9.0 {'HIM': 3, 'HE': 6}
# percentage for label as male: 0.00158842216731
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_5928.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7025
# For male:  22.0 {'HIM': 2, 'ACTOR': 2, 'HE': 18}
# percentage for label as male: 0.00313167259786
# For female:  2.0 {'GOOSE': 2}
# percentage for label as female: 0.000284697508897
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_603.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7721
# For male:  6.0 {'HE': 6}
# percentage for label as male: 0.000777101411734
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_637.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12306
# For male:  106.0 {'MAN': 1, 'HIM': 8, 'HUSBAND': 8, 'HE': 89}
# percentage for label as male: 0.0086136843816
# For female:  5.0 {'SHE': 1, 'WIFE': 4}
# percentage for label as female: 0.000406305867057
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_6432.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7289
# For male:  23.0 {'COUNT': 1, 'SIR': 1, 'HIM': 1, 'HE': 20}
# percentage for label as male: 0.00315543970366
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_6964.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9817
# For male:  37.0 {'HIM': 6, 'HE': 31}
# percentage for label as male: 0.0037689721911
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000305592339819
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_04_70.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# total number of words:  18905
# For male:  44.0 {'COUNT': 4, 'GENTLEMEN': 6, 'FATHER': 6, 'HIM': 3, 'HE': 25}
# percentage for label as male: 0.00232742660672
# For female:  12.0 {'SISTER': 6, 'MOTHER': 6}
# percentage for label as female: 0.000634752710923
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_105_orig.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5057
# For male:  101.0 {'MASTER': 76, 'HIM': 3, 'HE': 22}
# percentage for label as male: 0.0199723156021
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2004/AXBYA/2004_128_orig.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8956
# For male:  4.0 {'COUNT': 1, 'SIR': 1, 'HE': 2}
# percentage for label as male: 0.00044662795891
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
