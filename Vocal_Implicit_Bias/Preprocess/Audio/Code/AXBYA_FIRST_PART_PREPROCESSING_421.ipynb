# %%
import pandas as pd
import numpy as np
import os.path
#make sure gender_word.py is under the same folder
import gender_word
from nltk.tag.perceptron import PerceptronTagger

# %%
def get_start(path):

	print path+"oyez_full/fullTierName_"+myYear+".csv"
	whole_list = pd.read_csv(path+"oyez_full/fullTierName_"+myYear+".csv")
	
	#start point & end point
	index = 0
	row_num = whole_list.shape[0]
	tmp = 0

	#log file
	if os.path.isfile('log_'+myYear+'.bin'):
		with open("log_"+myYear+".bin","r") as log_file:
			log_content = log_file.readlines()[0].split(" ")
			if len(log_content)>0:
				index = int(log_content[-2])
				tmp = whole_list["TextGrid"][index]
				print ("Start from ",tmp)
			else:
				print ("log file is empty")
	else:
		print ("File doesn't exist.")
		print ("Start from begining")


	with open("log_"+myYear+".bin","a+") as log_file: 
		#go through every row in index file and record log
		while(index < row_num):
			if whole_list["useable"][index]==1:
				if tmp != whole_list["TextGrid"][index]:
					log_file.write(str(index)+" ")
					log_file.flush()
					tmp = whole_list["TextGrid"][index]
					year = whole_list["Year"][index]
					get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
			index += 1

# %%
def get_audio_feature(path,year,filename,whole_list):
	# for ABA format
	# path indicate the root direction for the whole data
	# filename represents .csv file for aba 
	# return an n*23 matrix contains speaker infomation, audio features and classify
	
	aba_table_info = pd.read_csv(path+"AXBYA/axbya_table_info.csv")
	filepath = path+"FAVE/FAVE-extract/"+myYear+"_vowels/AXBYA/"+str(filename)+".csv"

	#check exist
	if os.path.isfile(filepath)==False:
		return
	else:
		print path+"FAVE/FAVE-extract/"+myYear+"_vowels/AXBYA/"+str(filename)+".csv"

	feature_list = pd.read_csv(path+"FAVE/FAVE-extract/"+myYear+"_vowels/AXBYA/"+str(filename)+".csv")
	row_num = feature_list.shape[0]
	#illegal file
	if row_num == 0:
		return

	df = pd.DataFrame()

	index = 0.0
	number_m = 0.0;
	gender_word_male = {};
	number_w = 0.0;
	gender_word_female = {};
	speaker_id_map = {};
	vowel_id = {};
	pretrain = PerceptronTagger()

	counter1 = 0
	while (index < row_num):
		counter1+=1
		if(counter1 % 1000 == 0):
			print("Finished "+str(counter1)+" rows")
		text = feature_list["word"][index]
		identity_for_text = pretrain.tag([text])
		if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):#filter
			# record 
			classify = gender_word.G(text.lower());
			if classify == 1:
				value = gender_word_male.get(text, -1)
				if value != -1:
					gender_word_male[text] += 1
				else: 
					gender_word_male[text] = 1
				number_m += 1
			if classify == -1:
				value = gender_word_female.get(text, -1)
				if value!=-1:
					gender_word_female[text] += 1
				else:
					gender_word_female[text] = 1
				number_w += 1

			vowel = feature_list["vowel"][index]#added feature
			value = vowel_id.get(vowel, -1)
			if value == -1:
				vowel_id[vowel] = 1

			#decide who do the speach 
			speak_a_id = feature_list["speakerA1_id"][index]
			speak_b_id = feature_list["speakerB_id"][index]
			speak_x_id = feature_list["speakerY_id"][index]
			speak_y_id = feature_list["speakerX_id"][index]
			tier_num = feature_list["tiernum"][index]
			dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
			speaker_pattern = []
			if len(dt_row) > 0:
				speaker = whole_list["TierName"][dt_row].tolist()
				speakers = speaker[0].split(" ")
				for s in speakers:
					s_tmp = list(s)
					s_tmp[0] = s_tmp[0].upper()
					s = "".join(s_tmp)
					speaker_pattern.append(s)
			
			pattern = "|".join(speaker_pattern)

			dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&((aba_table_info["speakerA"].str.contains(pattern,na=False))|
				(aba_table_info["speakerB"].str.contains(pattern,na=False))|(aba_table_info["speakerX"].str.contains(pattern,na=False))|
				(aba_table_info["speakerY"].str.contains(pattern,na=False)))].index
			dt_row_2 = dt_row_tmp.tolist()
			if len(dt_row_2) != 0:
				speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
				value = speaker_id_map.get(speaker_id, -1)
				if value == -1:
					speaker_id_map[speaker_id] = 1
				
				text_feature_f1 = feature_list["F1"][index]
				text_feature_f2 = feature_list["F2"][index]
				text_feature_f3 = feature_list["F3"][index]
				text_feature_B1 = feature_list["B1"][index]
				text_feature_B2 = feature_list["B2"][index]
				text_feature_B3 = feature_list["B3"][index]
				text_feature_t = feature_list["t"][index]
				text_feature_beg = feature_list["beg"][index]
				text_feature_end = feature_list["end"][index]
				text_feature_dur = feature_list["dur"][index]
				text_feature_F120 = feature_list["F1@20%"][index]
				text_feature_F220 = feature_list["F2@20%"][index]
				text_feature_F135 = feature_list["F1@35%"][index]
				text_feature_F235 = feature_list["F2@35%"][index]
				text_feature_F150 = feature_list["F1@50%"][index]
				text_feature_F250 = feature_list["F2@50%"][index]
				text_feature_F160 = feature_list["F1@65%"][index]
				text_feature_F260 = feature_list["F2@65%"][index]
				text_feature_F180 = feature_list["F1@80%"][index]
				text_feature_F280 = feature_list["F2@80%"][index]
				tmp_data = np.array([speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
					text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
					text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
					text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify]).reshape(1,22)
				test_data_tmp = pd.DataFrame(tmp_data,columns=['speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
					'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify'])
				test_data_tmp['docket_id'] = filename
				test_data_tmp['identity'] = identity_for_text[0][1]
				test_data_tmp['text'] = text
				test_data_tmp['vowel'] = vowel
				df = df.append(test_data_tmp,ignore_index=True)
		index += 1

	# extract mean
	mean_df = pd.DataFrame()
	for key in speaker_id_map:
		for key_2 in vowel_id:
			df_tmp = df[(df['speaker_id']==key)&(df['vowel']==key_2)].mean()
			df_tmp['speaker_id'] = key;
			df_tmp['vowel'] = key_2
			mean_df = mean_df.append(df_tmp,ignore_index=True)
	if df.shape[0]!=0:

		new_colom_f1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f3 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_B1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_B2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_B3 = pd.Series(np.zeros(df.shape[0]), index=df.index)

		new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)

		for i_new in range(df.shape[0]):
			mean_df_id = mean_df[(mean_df['speaker_id']==float(df['speaker_id'][i_new]))&(mean_df['vowel']==df['vowel'][i_new])]
			new_colom_f1[i_new] = df['f1'][i_new]- mean_df_id['f1']
			new_colom_f2[i_new] = df['f2'][i_new]- mean_df_id['f2']
			new_colom_f3[i_new] = df['f3'][i_new]- mean_df_id['f3']
			new_colom_B1[i_new] = df['B1'][i_new]- mean_df_id['B1']
			new_colom_B2[i_new] = df['B2'][i_new]- mean_df_id['B2']
			new_colom_B3[i_new] = df['B3'][i_new]- mean_df_id['B3']

			new_colom_f1_20[i_new] = df['f1@20%'][i_new]- mean_df_id['f1@20%']
			new_colom_f1_35[i_new] = df['f1@35%'][i_new]- mean_df_id['f1@35%']
			new_colom_f1_50[i_new] = df['f1@50%'][i_new]- mean_df_id['f1@50%']
			new_colom_f1_60[i_new] = df['f1@60%'][i_new]- mean_df_id['f1@60%']
			new_colom_f1_80[i_new] = df['f1@80%'][i_new]- mean_df_id['f1@80%']
			new_colom_f2_20[i_new] = df['f2@20%'][i_new]- mean_df_id['f2@20%']
			new_colom_f2_35[i_new] = df['f2@35%'][i_new]- mean_df_id['f2@35%']
			new_colom_f2_50[i_new] = df['f2@50%'][i_new]- mean_df_id['f2@50%']
			new_colom_f2_60[i_new] = df['f2@60%'][i_new]- mean_df_id['f2@60%']
			new_colom_f2_80[i_new] = df['f2@80%'][i_new]- mean_df_id['f2@80%']

		# add new column
		df['f1_c'] = new_colom_f1
		df['f2_c'] = new_colom_f2
		df['f3_c'] = new_colom_f3
		df['B1_c'] = new_colom_B1
		df['B2_c'] = new_colom_B2
		df['B3_c'] = new_colom_B3

		df['f1@20%_c'] = new_colom_f1_20
		df['f1@35%_c'] = new_colom_f1_35
		df['f1@50%_c'] = new_colom_f1_50
		df['f1@60%_c'] = new_colom_f1_60
		df['f1@80%_c'] = new_colom_f1_80
		df['f2@20%_c'] = new_colom_f2_20
		df['f2@35%_c'] = new_colom_f2_35
		df['f2@50%_c'] = new_colom_f2_50
		df['f2@60%_c'] = new_colom_f2_60
		df['f2@80%_c'] = new_colom_f2_80
		# save or add these column into the audio_feature.csv file
		if not os.path.isfile('audio_feature_axbya_'+myYear+'.csv'):
			df.to_csv('audio_feature_axbya_'+myYear+'.csv',header ='column_names',index = False)
		else:
			df.to_csv('audio_feature_axbya_'+myYear+'.csv',mode = 'a',header=False,index = False)
	
	print "total number of words: ",row_num
	print "For male: ",number_m,gender_word_male
	print "percentage for label as male:",number_m/row_num
	print "For female: ",number_w,gender_word_female
	print "percentage for label as female:",number_w/row_num
	print ""
	return

# %%
root_path = "./"#dropbox address
myYear="2010"
get_start(root_path)
# Out:
# ./oyez_full/fullTierName_2010.csv
# File doesn't exist.
# Start from begining
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_08_1314.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7873
# For male:  1.0 {'HE': 1}
# percentage for label as male: 0.000127016385114
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_08_1423.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8290
# For male:  33.0 {'KING': 21, 'SIR': 1, 'HE': 11}
# percentage for label as male: 0.00398069963812
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_08_1448.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8957
# For male:  2.0 {'HIM': 1, 'HE': 1}
# percentage for label as male: 0.000223289047672
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1036.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# total number of words:  10494
# For male:  44.0 {'HIM': 6, 'DOG': 2, 'HE': 36}
# percentage for label as male: 0.0041928721174
# For female:  2.0 {'WIFE': 2}
# percentage for label as female: 0.000190585096245
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1088.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# total number of words:  13111
# For male:  58.0 {'HIM': 2, 'HE': 56}
# percentage for label as male: 0.0044237663031
# For female:  4.0 {'MOTHER': 4}
# percentage for label as female: 0.000305087331249
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_115.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# total number of words:  4713
# For male:  1.0 {'HE': 1}
# percentage for label as male: 0.000212179079143
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1227.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5609
# For male:  3.0 {'HE': 3}
# percentage for label as male: 0.000534854697807
# For female:  14.0 {'WOMAN': 2, 'SHE': 12}
# percentage for label as female: 0.00249598858977
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1272.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7728
# For male:  33.0 {'POLICEMAN': 6, 'HIM': 1, 'DRAKE': 1, 'HE': 25}
# percentage for label as male: 0.0042701863354
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000388198757764
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1273.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5876
# For male:  2.0 {'ACTOR': 2}
# percentage for label as male: 0.000340367597005
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000170183798502
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1279.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5844
# For male:  3.0 {'HIM': 2, 'HE': 1}
# percentage for label as male: 0.000513347022587
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1298.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7883
# For male:  3.0 {'HE': 3}
# percentage for label as male: 0.000380565774451
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1343.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# total number of words:  15645
# For male:  56.0 {'COUNT': 3, 'KING': 2, 'MAN': 3, 'SIR': 2, 'HE': 46}
# percentage for label as male: 0.00357941834452
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1403.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# total number of words:  4421
# For male:  1.0 {'HE': 1}
# percentage for label as male: 0.000226193168966
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1454.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8152
# For male:  32.0 {'POLICEMAN': 3, 'FATHER': 6, 'HIM': 4, 'HE': 19}
# percentage for label as male: 0.00392541707556
# For female:  27.0 {'WOMAN': 2, 'SHE': 25}
# percentage for label as female: 0.00331207065751
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_1476.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# total number of words:  6901
# For male:  9.0 {'COUNT': 1, 'HIM': 1, 'HE': 7}
# percentage for label as male: 0.00130415881756
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_291.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8381
# For male:  53.0 {'MAN': 1, 'HUSBAND': 2, 'HIM': 14, 'LANDLORD': 4, 'HE': 32}
# percentage for label as male: 0.00632382770552
# For female:  52.0 {'FIANCEE': 24, 'WOMAN': 4, 'DAUGHTER': 2, 'SHE': 19, 'WIFE': 3}
# percentage for label as female: 0.00620451020165
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_329.csv
# total number of words:  855
# For male:  1.0 {'HE': 1}
# percentage for label as male: 0.00116959064327
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_400.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# total number of words:  9992
# For male:  94.0 {'BUCK': 11, 'SIR': 2, 'GENTLEMAN': 3, 'ACTOR': 2, 'HIM': 25, 'HE': 51}
# percentage for label as male: 0.00940752602082
# For female:  33.0 {'SHE': 33}
# percentage for label as female: 0.00330264211369
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_525.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# total number of words:  12076
# For male:  42.0 {'HIM': 3, 'ACTOR': 4, 'HE': 35}
# percentage for label as male: 0.00347797283869
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_529.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8829
# For male:  20.0 {'HIM': 4, 'HE': 16}
# percentage for label as male: 0.0022652622041
# For female:  3.0 {'DAM': 3}
# percentage for label as female: 0.000339789330615
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_530.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# total number of words:  9982
# For male:  4.0 {'HIM': 2, 'HE': 2}
# percentage for label as male: 0.000400721298337
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_571.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7116
# For male:  38.0 {'HIM': 2, 'ACTOR': 2, 'HE': 34}
# percentage for label as male: 0.0053400786959
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000421585160202
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_658.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# total number of words:  3652
# For male:  80.0 {'HIM': 12, 'MAN': 1, 'SIR': 1, 'BROTHER': 22, 'HE': 44}
# percentage for label as male: 0.0219058050383
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_737.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5070
# For male:  13.0 {'POLICEMAN': 3, 'HE': 10}
# percentage for label as male: 0.0025641025641
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000591715976331
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_751.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# total number of words:  12414
# For male:  79.0 {'SIR': 1, 'FATHER': 4, 'DOG': 2, 'SON': 12, 'PRIEST': 3, 'HIM': 8, 'HE': 49}
# percentage for label as male: 0.00636378282584
# For female:  34.0 {'GRANDMOTHER': 27, 'WOMAN': 4, 'SHE': 3}
# percentage for label as female: 0.0027388432415
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_804.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# total number of words:  6229
# For male:  1.0 {'HE': 1}
# percentage for label as male: 0.000160539412426
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000160539412426
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_837.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8172
# For male:  15.0 {'COUNT': 2, 'HIM': 2, 'HE': 11}
# percentage for label as male: 0.00183553597651
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_868.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# total number of words:  13081
# For male:  39.0 {'HE': 38, 'MAN': 1}
# percentage for label as male: 0.00298142343858
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_907.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7413
# For male:  31.0 {'HIM': 4, 'HE': 27}
# percentage for label as male: 0.00418184270875
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_987.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# total number of words:  9686
# For male:  1.0 {'PRIEST': 1}
# percentage for label as male: 0.000103241792278
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_09_996.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8025
# For male:  18.0 {'COUNT': 6, 'DUKE': 1, 'HIM': 4, 'HE': 7}
# percentage for label as male: 0.00224299065421
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_174.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# total number of words:  10078
# For male:  5.0 {'HIM': 1, 'HE': 4}
# percentage for label as male: 0.00049613018456
# For female:  1.0 {'COW': 1}
# percentage for label as female: 9.92260369121e-05
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_179.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7197
# For male:  18.0 {'HIM': 1, 'HE': 17}
# percentage for label as male: 0.00250104210088
# For female:  6.0 {'SHE': 6}
# percentage for label as female: 0.000833680700292
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_188.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# total number of words:  10409
# For male:  29.0 {'COUNT': 5, 'HIM': 2, 'HE': 22}
# percentage for label as male: 0.00278605053319
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_235.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5849
# For male:  8.0 {'HE': 8}
# percentage for label as male: 0.00136775517182
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_238.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# total number of words:  7186
# For male:  12.0 {'HIM': 4, 'HE': 8}
# percentage for label as male: 0.00166991372112
# For female:  2.0 {'SHE': 2}
# percentage for label as female: 0.000278318953521
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_277.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# total number of words:  9050
# For male:  3.0 {'HIM': 1, 'HE': 2}
# percentage for label as male: 0.000331491712707
# For female:  14.0 {'WOMAN': 8, 'SHE': 6}
# percentage for label as female: 0.00154696132597
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_290.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# total number of words:  4103
# For male:  5.0 {'HIM': 1, 'HE': 4}
# percentage for label as male: 0.00121862052157
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_382.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# total number of words:  10143
# For male:  15.0 {'HIM': 2, 'HE': 13}
# percentage for label as male: 0.00147885241053
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_5258.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5384
# For male:  49.0 {'COUNT': 4, 'HIM': 8, 'ACTOR': 6, 'HE': 31}
# percentage for label as male: 0.00910104011887
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_5400.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# total number of words:  5579
# For male:  30.0 {'HE': 28, 'HIM': 1, 'MAN': 1}
# percentage for label as male: 0.00537730776125
# For female:  32.0 {'WOMAN': 2, 'SHE': 30}
# percentage for label as female: 0.00573579494533
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_568.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# total number of words:  8929
# For male:  39.0 {'COUNCILMAN': 3, 'HIM': 10, 'HE': 26}
# percentage for label as male: 0.00436779034606
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_6.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# total number of words:  10680
# For male:  27.0 {'GIANT': 6, 'HIM': 5, 'HE': 16}
# percentage for label as male: 0.00252808988764
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_76.csv
# Finished 1000 rows
# total number of words:  1540
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2010_vowels/AXBYA/2010_10_779.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# total number of words:  11954
# For male:  34.0 {'SALESMAN': 4, 'HIM': 14, 'HE': 16}
# percentage for label as male: 0.00284423623892
# For female:  0.0 {}
# percentage for label as female: 0.0
