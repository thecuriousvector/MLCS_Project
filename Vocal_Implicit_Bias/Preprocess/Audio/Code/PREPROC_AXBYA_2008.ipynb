# %%
import pandas as pd
import numpy as np
import os.path
#make sure gender_word.py is under the same folder
from nltk.tag.perceptron import PerceptronTagger
import nltk
#nltk.download_shell()
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/richadeshmukh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
gender_dictionary = {}
male_list = open("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/text/male_list.txt", 'r')
female_list = open("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/text/female_list.txt", 'r')

for word in male_list:
    male_key = word.rstrip('\n')
    gender_dictionary[male_key] = 1

for word in female_list:
    female_key = word.rstrip('\n')
    gender_dictionary[female_key] = -1

male_list.close()
female_list.close()

def G(word):
    '''
    A function that accepts a string as an argument and returns the gender associated with 
    the string.

    Args
    ----
    word - a str

    Returns
    -------
    1  - if the word is in gender_dictionary and gender_dictionary[word] = 1
    -1 - if the word is in gender_dictionary and gender_dictioanry[word] = -1
    0  - if the word is not in gender_dictionary
    '''
    return gender_dictionary.get(word, 0)

# %%
def get_start(path):

    print "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2008.csv"
    whole_list = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2008.csv")
    
    #start point & end point
    index = 0
    row_num = whole_list.shape[0]
    tmp = 0

    #log file
    if os.path.isfile('log_2008.bin'):
        with open("log_2008.bin","r") as log_file:
            log_content = log_file.readlines()[0].split(" ")
            if len(log_content)>0:
                index = int(log_content[-2])
                tmp = whole_list["TextGrid"][index]
                print ("Start from ",tmp)
            else:
                print ("log file is empty")
    else:
        print ("File doesn't exist.")
        print ("Start from begining")


    with open("log_2008.bin","a+") as log_file: 
        #go through every row in index file and record log
        counter1=1
        while(index < row_num):
            print("Counter1 is "+str(counter1)+"\n")
            if whole_list["useable"][index]==1:
                if tmp != whole_list["TextGrid"][index]:
                    log_file.write(str(index)+" ")
                    log_file.flush()
                    tmp = whole_list["TextGrid"][index]
                    year = whole_list["Year"][index]
                    get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
            index += 1

# %%
def get_audio_feature(path,year,filename,whole_list):
    # for ABA format
    # path indicate the root direction for the whole data
    # filename represents .csv file for aba 
    # return an n*23 matrix contains speaker infomation, audio features and classify
    
    aba_table_info = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/axbya_table_info.csv")
    filepath = "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/"+str(filename)+".csv"
    #check exist
    if os.path.isfile(filepath)==False:
        return
    else:
        print "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/"+str(filename)+".csv"
    feature_list = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/"+str(filename)+".csv")
    row_num = feature_list.shape[0]
    #illegal file
    if row_num == 0:
        return

    df = pd.DataFrame()
    index = 0.0
    number_m = 0.0;
    gender_word_male = {};
    number_w = 0.0;
    gender_word_female = {};
    speaker_id_map = {};
    vowel_id = {};
    pretrain = PerceptronTagger()
    counter2=0;
    while (index < row_num):
        counter2+=1
        if(counter2%1000 == 0):
            print("Completed reading rows"+str(counter2))
        text = feature_list["word"][index]
        identity_for_text = pretrain.tag([text])
        if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):#filter
            # record 
            classify = G(text.lower());
            if classify == 1:
                value = gender_word_male.get(text, -1)
                if value != -1:
                    gender_word_male[text] += 1
                else: 
                    gender_word_male[text] = 1
                number_m += 1
            if classify == -1:
                value = gender_word_female.get(text, -1)
                if value!=-1:
                    gender_word_female[text] += 1
                else:
                    gender_word_female[text] = 1
                number_w += 1

            vowel = feature_list["vowel"][index]#added feature
            value = vowel_id.get(vowel, -1)
            if value == -1:
                vowel_id[vowel] = 1

            #decide who do the speach 
            speak_a_id = feature_list["speakerA1_id"][index]
            speak_b_id = feature_list["speakerB_id"][index]
            speak_x_id = feature_list["speakerY_id"][index]
            speak_y_id = feature_list["speakerX_id"][index]
            tier_num = feature_list["tiernum"][index]
            dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
            speaker_pattern = []
            if len(dt_row) > 0:
                speaker = whole_list["TierName"][dt_row].tolist()
                speakers = speaker[0].split(" ")
                for s in speakers:
                    s_tmp = list(s)
                    s_tmp[0] = s_tmp[0].upper()
                    s = "".join(s_tmp)
                    speaker_pattern.append(s)
            
            pattern = "|".join(speaker_pattern)

            dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&((aba_table_info["speakerA"].str.contains(pattern,na=False))|
                (aba_table_info["speakerB"].str.contains(pattern,na=False))|(aba_table_info["speakerX"].str.contains(pattern,na=False))|
                (aba_table_info["speakerY"].str.contains(pattern,na=False)))].index
            dt_row_2 = dt_row_tmp.tolist()
            if len(dt_row_2) != 0:
                speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
                value = speaker_id_map.get(speaker_id, -1)
                if value == -1:
                    speaker_id_map[speaker_id] = 1
                
                text_feature_f1 = feature_list["F1"][index]
                text_feature_f2 = feature_list["F2"][index]
                text_feature_f3 = feature_list["F3"][index]
                text_feature_B1 = feature_list["B1"][index]
                text_feature_B2 = feature_list["B2"][index]
                text_feature_B3 = feature_list["B3"][index]
                text_feature_t = feature_list["t"][index]
                text_feature_beg = feature_list["beg"][index]
                text_feature_end = feature_list["end"][index]
                text_feature_dur = feature_list["dur"][index]
                text_feature_F120 = feature_list["F1@20%"][index]
                text_feature_F220 = feature_list["F2@20%"][index]
                text_feature_F135 = feature_list["F1@35%"][index]
                text_feature_F235 = feature_list["F2@35%"][index]
                text_feature_F150 = feature_list["F1@50%"][index]
                text_feature_F250 = feature_list["F2@50%"][index]
                text_feature_F160 = feature_list["F1@65%"][index]
                text_feature_F260 = feature_list["F2@65%"][index]
                text_feature_F180 = feature_list["F1@80%"][index]
                text_feature_F280 = feature_list["F2@80%"][index]
                tmp_data = np.array([speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
                    text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
                    text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
                    text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify]).reshape(1,22)
                test_data_tmp = pd.DataFrame(tmp_data,columns=['speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
                    'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify'])
                test_data_tmp['docket_id'] = filename
                test_data_tmp['identity'] = identity_for_text[0][1]
                test_data_tmp['text'] = text
                test_data_tmp['vowel'] = vowel
                df = df.append(test_data_tmp,ignore_index=True)
        index += 1

    # extract mean
    mean_df = pd.DataFrame()
    for key in speaker_id_map:
        for key_2 in vowel_id:
            df_tmp = df[(df['speaker_id']==key)&(df['vowel']==key_2)].mean()
            df_tmp['speaker_id'] = key;
            df_tmp['vowel'] = key_2
            mean_df = mean_df.append(df_tmp,ignore_index=True)
    if df.shape[0]!=0:

        new_colom_f1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f3 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B3 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        for i_new in range(df.shape[0]):
            mean_df_id = mean_df[(mean_df['speaker_id']==float(df['speaker_id'][i_new]))&(mean_df['vowel']==df['vowel'][i_new])]
            new_colom_f1[i_new] = df['f1'][i_new]- mean_df_id['f1']
            new_colom_f2[i_new] = df['f2'][i_new]- mean_df_id['f2']
            new_colom_f3[i_new] = df['f3'][i_new]- mean_df_id['f3']
            new_colom_B1[i_new] = df['B1'][i_new]- mean_df_id['B1']
            new_colom_B2[i_new] = df['B2'][i_new]- mean_df_id['B2']
            new_colom_B3[i_new] = df['B3'][i_new]- mean_df_id['B3']

            new_colom_f1_20[i_new] = df['f1@20%'][i_new]- mean_df_id['f1@20%']
            new_colom_f1_35[i_new] = df['f1@35%'][i_new]- mean_df_id['f1@35%']
            new_colom_f1_50[i_new] = df['f1@50%'][i_new]- mean_df_id['f1@50%']
            new_colom_f1_60[i_new] = df['f1@60%'][i_new]- mean_df_id['f1@60%']
            new_colom_f1_80[i_new] = df['f1@80%'][i_new]- mean_df_id['f1@80%']
            new_colom_f2_20[i_new] = df['f2@20%'][i_new]- mean_df_id['f2@20%']
            new_colom_f2_35[i_new] = df['f2@35%'][i_new]- mean_df_id['f2@35%']
            new_colom_f2_50[i_new] = df['f2@50%'][i_new]- mean_df_id['f2@50%']
            new_colom_f2_60[i_new] = df['f2@60%'][i_new]- mean_df_id['f2@60%']
            new_colom_f2_80[i_new] = df['f2@80%'][i_new]- mean_df_id['f2@80%']

        # add new column
        df['f1_c'] = new_colom_f1
        df['f2_c'] = new_colom_f2
        df['f3_c'] = new_colom_f3
        df['B1_c'] = new_colom_B1
        df['B2_c'] = new_colom_B2
        df['B3_c'] = new_colom_B3

        df['f1@20%_c'] = new_colom_f1_20
        df['f1@35%_c'] = new_colom_f1_35
        df['f1@50%_c'] = new_colom_f1_50
        df['f1@60%_c'] = new_colom_f1_60
        df['f1@80%_c'] = new_colom_f1_80
        df['f2@20%_c'] = new_colom_f2_20
        df['f2@35%_c'] = new_colom_f2_35
        df['f2@50%_c'] = new_colom_f2_50
        df['f2@60%_c'] = new_colom_f2_60
        df['f2@80%_c'] = new_colom_f2_80
        # save or add these column into the audio_feature.csv file
        if not os.path.isfile('audio_feature_axbya_2008.csv'):
            df.to_csv('audio_feature_axbya_2008.csv',header ='column_names',index = False)
        else:
            df.to_csv('audio_feature_axbya_2008.csv',mode = 'a',header=False,index = False)
    
    print "total number of words: ",row_num
    print "For male: ",number_m,gender_word_male
    print "percentage for label as male:",number_m/row_num
    print "For female: ",number_w,gender_word_female
    print "percentage for label as female:",number_w/row_num
    print ""
    return

# %%
data_dir = '/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2005/AXBYA/'
output_dir = '/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2005/AXBYA/'
get_start(data_dir)
# Out:
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2008.csv
# ('Start from ', '2008_06_11206.TextGrid')
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_10441.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8683
# For male:  8.0 {'HIM': 5, 'HE': 3}
# percentage for label as male: 0.000921340550501
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1125.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11029
# For male:  14.0 {'HIM': 2, 'HE': 12}
# percentage for label as male: 0.00126938072355
# For female:  3.0 {'SHE': 1, 'FEMALE': 2}
# percentage for label as female: 0.000272010155046
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1209.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10842
# For male:  41.0 {'COUNT': 2, 'MAN': 2, 'HIM': 10, 'HE': 27}
# percentage for label as male: 0.00378159011253
# For female:  39.0 {'SHE': 39}
# percentage for label as female: 0.00359712230216
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1315.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12057
# For male:  101.0 {'HOST': 2, 'HIM': 6, 'HE': 93}
# percentage for label as male: 0.00837687650328
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1356.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7069
# For male:  85.0 {'HIM': 5, 'HE': 80}
# percentage for label as male: 0.0120243315886
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1372.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7087
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1437.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9662
# For male:  6.0 {'HE': 6}
# percentage for label as male: 0.000620989443179
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_1601.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10853
# For male:  22.0 {'HIM': 1, 'HE': 21}
# percentage for label as male: 0.00202708928407
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000276421266009
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_463.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9890
# For male:  19.0 {'HE': 19}
# percentage for label as male: 0.00192113245703
# For female:  2.0 {'WITCH': 2}
# percentage for label as female: 0.000202224469161
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_499.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# total number of words:  15241
# For male:  61.0 {'HIM': 14, 'HE': 47}
# percentage for label as male: 0.00400236204973
# For female:  10.0 {'WOMAN': 10}
# percentage for label as female: 0.000656124926186
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_526.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10556
# For male:  22.0 {'CONGRESSMAN': 6, 'HIM': 2, 'HE': 14}
# percentage for label as male: 0.00208412277378
# For female:  1.0 {'COW': 1}
# percentage for label as female: 9.47328533535e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_543.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# total number of words:  13530
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  4.0 {'WOMAN': 2, 'SHE': 2}
# percentage for label as female: 0.00029563932003
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_544.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9640
# For male:  40.0 {'NEPHEW': 4, 'UNCLE': 8, 'HIM': 1, 'HE': 27}
# percentage for label as male: 0.00414937759336
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_562.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8852
# For male:  5.0 {'MASTER': 2, 'HIM': 2, 'MAN': 1}
# percentage for label as male: 0.000564844103028
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_581.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7595
# For male:  11.0 {'HIM': 2, 'HE': 9}
# percentage for label as male: 0.00144832126399
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_588.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9509
# For male:  11.0 {'HE': 11}
# percentage for label as male: 0.00115679882217
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_591.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9895
# For male:  31.0 {'SIR': 1, 'POLICEMAN': 6, 'HIM': 3, 'HE': 21}
# percentage for label as male: 0.00313289540172
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_608.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10196
# For male:  61.0 {'HE': 61}
# percentage for label as male: 0.00598273832876
# For female:  2.0 {'WIFE': 2}
# percentage for label as female: 0.000196155355041
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_615.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# total number of words:  14366
# For male:  3.0 {'HIM': 1, 'HE': 2}
# percentage for label as male: 0.000208826395656
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_689.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10064
# For male:  2.0 {'BROTHER': 2}
# percentage for label as male: 0.000198728139905
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_6984.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11413
# For male:  152.0 {'COUNT': 5, 'SIR': 1, 'MAN': 1, 'HIM': 9, 'HE': 136}
# percentage for label as male: 0.0133181459739
# For female:  2.0 {'SHE': 2}
# percentage for label as female: 0.000175238762814
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_8521.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# total number of words:  13822
# For male:  63.0 {'CONGRESSMAN': 3, 'SIR': 1, 'HIM': 12, 'HE': 47}
# percentage for label as male: 0.00455795109246
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_854.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7993
# For male:  41.0 {'BUCK': 2, 'LAYMAN': 8, 'HIM': 5, 'ACTOR': 4, 'HE': 22}
# percentage for label as male: 0.00512948830226
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000125109470787
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_869.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# total number of words:  13159
# For male:  4.0 {'HIM': 1, 'HE': 3}
# percentage for label as male: 0.000303974466145
# For female:  2.0 {'DAM': 2}
# percentage for label as female: 0.000151987233072
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_901.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8016
# For male:  11.0 {'COUNT': 2, 'HIM': 2, 'HE': 7}
# percentage for label as male: 0.00137225548902
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_9712.csv
# total number of words:  83
# For male:  1.0 {'HE': 1}
# percentage for label as male: 0.0120481927711
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_07_9995.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11371
# For male:  20.0 {'HIM': 4, 'HE': 16}
# percentage for label as male: 0.00175886025855
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 8.79430129276e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_108.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7467
# For male:  60.0 {'MAN': 4, 'HIM': 3, 'HE': 53}
# percentage for label as male: 0.00803535556448
# For female:  5.0 {'DOE': 1, 'MOTHER': 4}
# percentage for label as female: 0.000669612963707
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_146.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# total number of words:  14018
# For male:  36.0 {'HIM': 11, 'HE': 25}
# percentage for label as male: 0.00256812669425
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_192.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10643
# For male:  28.0 {'HOST': 2, 'HE': 21, 'HIM': 4, 'MAN': 1}
# percentage for label as male: 0.00263083716997
# For female:  8.0 {'WOMAN': 4, 'SHE': 4}
# percentage for label as female: 0.000751667762849
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_205.csv
# Completed reading rows1000
# total number of words:  1362
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_214.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5979
# For male:  42.0 {'COUNT': 1, 'MASTER': 4, 'LORD': 1, 'LONGSHOREMAN': 6, 'HIM': 10, 'HE': 20}
# percentage for label as male: 0.00702458605118
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_267.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# total number of words:  14565
# For male:  78.0 {'HIM': 8, 'COUNCILMAN': 6, 'HE': 64}
# percentage for label as male: 0.0053553038105
# For female:  1.0 {'DOE': 1}
# percentage for label as female: 6.86577411603e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_289.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9524
# For male:  12.0 {'CONGRESSMAN': 3, 'HIM': 2, 'HE': 7}
# percentage for label as male: 0.0012599748005
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_295.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12163
# For male:  6.0 {'HE': 4, 'HIM': 1, 'MAN': 1}
# percentage for label as male: 0.000493299350489
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_305.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10702
# For male:  9.0 {'COUNT': 2, 'HIM': 4, 'HE': 3}
# percentage for label as male: 0.000840964305737
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_322.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9547
# For male:  1.0 {'HOST': 1}
# percentage for label as male: 0.000104744946056
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_479.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12935
# For male:  47.0 {'COUNT': 1, 'MAN': 3, 'HIM': 4, 'HE': 39}
# percentage for label as male: 0.00363355237727
# For female:  66.0 {'SHE': 58, 'FEMALE': 2, 'MOTHER': 6}
# percentage for label as female: 0.00510243525319
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_495.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11929
# For male:  19.0 {'HIM': 5, 'HE': 14}
# percentage for label as male: 0.00159275714645
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_598.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7007
# For male:  21.0 {'HIM': 2, 'BROTHER': 4, 'HE': 15}
# percentage for label as male: 0.002997002997
# For female:  4.0 {'SHE': 4}
# percentage for label as female: 0.000570857713715
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_6.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# total number of words:  16222
# For male:  258.0 {'SIR': 1, 'HOST': 1, 'HIM': 47, 'HE': 209}
# percentage for label as male: 0.0159043274565
# For female:  6.0 {'SHE': 2, 'MOTHER': 4}
# percentage for label as female: 0.000369868080385
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2008/AXBYA/2008_08_67.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9845
# For male:  80.0 {'COUNT': 56, 'HIM': 13, 'HE': 11}
# percentage for label as male: 0.00812595226003
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
