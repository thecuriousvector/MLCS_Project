# %%
import pandas as pd
import numpy as np
import os.path
#make sure gender_word.py is under the same folder
import gender_word
from nltk.tag.perceptron import PerceptronTagger

# %%
def get_start(path):

	print path+"oyez_full/fullTierName_"+myYear+".csv"# change to the proper direction
	whole_list = pd.read_csv(path+"oyez_full/fullTierName_"+myYear+".csv")#contain infomation about all audio text transcription file
	
	#start point
	index = 0
	
	row_num = whole_list.shape[0]
	tmp = 1
	text_grid = 0#text_grid for 
	year = 0
	tier_dictionary={}

	while(index < row_num):
		if whole_list["useable"][index]==1:
			#indicate a new file
			if tmp != whole_list["TextGrid"][index]:
				tmp = whole_list["TextGrid"][index]
				year = whole_list["Year"][index]
				get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
		index += 1

# %%
def get_audio_feature(path,year,filename,whole_list):
	# for ABA format
	# path indicate the root direction for the whole data
	# filename represents .csv file for aba 
	# return an n*23 matrix contains speaker infomation, audio features and classify
	audio_matrix = np.empty((0,23))
	aba_table_info = pd.read_csv(path+"ABA/aba_table_info.csv")
	filepath = path+"FAVE/FAVE-extract/"+myYear+"_vowels/ABA/"+str(filename)+".csv"
	if os.path.isfile(filepath)==False:
		return
	else:
		print path+"FAVE/FAVE-extract/"+myYear+"_vowels/ABA/"+str(filename)+".csv"
	feature_list = pd.read_csv(path+"FAVE/FAVE-extract/"+myYear+"_vowels/ABA/"+str(filename)+".csv")
	row_num = feature_list.shape[0]#all word extracted from the get_audio_feature
	if row_num == 0:
		return
	#fpr de-mean purpose 
	id_tmp = 0
	docket_id = 0
	# Create an empty dataframe
	df = pd.DataFrame()

	index = 0.0
	number_m = 0.0;
	gender_word_male = {};
	number_w = 0.0;
	gender_word_female = {};
	speaker_id_map = {};
	vowel_id = {};
	counter1 = 0
	while (index < row_num):
		counter1+=1
		if(counter1 % 1000 == 0):
			print("Finished "+str(counter1)+" rows")
		speak_a_id = feature_list["speakerA1_id"][index]#speaker A correspond to aba_table_info.csv
		speak_b_id = feature_list["speakerB_id"][index]#speaker B
		tier_num = feature_list["tiernum"][index]#decide who is speaking, correspond to textgrid file
		dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
		speaker_pattern = []
		if len(dt_row) > 0:
			speaker = whole_list["TierName"][dt_row].tolist()
			speakers = speaker[0].split(" ")
			for s in speakers:
				s_tmp = list(s)
				s_tmp[0] = s_tmp[0].upper()
				s = "".join(s_tmp)
				speaker_pattern.append(s)
		
		pattern = "|".join(speaker_pattern)
		text = feature_list["word"][index]#text, specific words
		pretrain = PerceptronTagger()
		identity_for_text = pretrain.tag([text])
		#filter
		if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):
			classify = gender_word.G(text.lower());
			if classify == 1:
				value = gender_word_male.get(text, -1)
				if value != -1:
					gender_word_male[text] += 1
				else: 
					gender_word_male[text] = 1
				number_m += 1
			if classify == -1:
				value = gender_word_female.get(text, -1)
				if value!=-1:
					gender_word_female[text] += 1
				else:
					gender_word_female[text] = 1
				number_w += 1
			vowel = feature_list["vowel"][index]#added feature
			value = vowel_id.get(vowel, -1)
			if value == -1:
				vowel_id[vowel] = 1

			text_feature_f1 = feature_list["F1"][index]
			text_feature_f2 = feature_list["F2"][index]
			text_feature_f3 = feature_list["F3"][index]
			text_feature_B1 = feature_list["B1"][index]
			text_feature_B2 = feature_list["B2"][index]
			text_feature_B3 = feature_list["B3"][index]
			text_feature_t = feature_list["t"][index]
			text_feature_beg = feature_list["beg"][index]
			text_feature_end = feature_list["end"][index]
			text_feature_dur = feature_list["dur"][index]
			text_feature_F120 = feature_list["F1@20%"][index]
			text_feature_F220 = feature_list["F2@20%"][index]
			text_feature_F135 = feature_list["F1@35%"][index]
			text_feature_F235 = feature_list["F2@35%"][index]
			text_feature_F150 = feature_list["F1@50%"][index]
			text_feature_F250 = feature_list["F2@50%"][index]
			text_feature_F160 = feature_list["F1@65%"][index]
			text_feature_F260 = feature_list["F2@65%"][index]
			text_feature_F180 = feature_list["F1@80%"][index]
			text_feature_F280 = feature_list["F2@80%"][index]

	
			dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&(aba_table_info["speakerA"].str.contains(pattern,na=False))].index
			dt_row_2 = dt_row_tmp.tolist()
			if len(dt_row_2) != 0:
				#find speaker id 
				#save validated data
				speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
				value = speaker_id_map.get(speaker_id, -1)
				if value == -1:
					speaker_id_map[speaker_id] = 1
				
				tmp_data = np.array([speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
					text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
					text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
					text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify]).reshape(1,22)
				test_data_tmp = pd.DataFrame(tmp_data,columns=['speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
					'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify'])
				test_data_tmp['docket_id'] = filename
				test_data_tmp['identity'] = identity_for_text[0][1]
				test_data_tmp['text'] = text
				test_data_tmp['vowel'] = vowel
				#test_data_tmp[['f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%']] = test_data_tmp[['f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%']].apply(pd.to_numeric,errors='coerce')
				df = df.append(test_data_tmp,ignore_index=True)
		index += 1
	#deal with the last person in this speech
	# de-mean
	id_tmp = 0
	docket_id_tmp = 0
	# extract mean
	mean_df = pd.DataFrame()
	for key in speaker_id_map:
		for key_2 in vowel_id:
			df_tmp = df[(df['speaker_id']==key)&(df['vowel']==key_2)].mean()
			df_tmp['speaker_id'] = key;
			df_tmp['vowel'] = key_2
			mean_df = mean_df.append(df_tmp,ignore_index=True)
	if df.shape[0]!=0:
	# not empty
	# define new column
		new_colom_f1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f3 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_B1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_B2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_B3 = pd.Series(np.zeros(df.shape[0]), index=df.index)

		new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
		new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)

		for i_new in range(df.shape[0]):
			mean_df_id = mean_df[(mean_df['speaker_id']==float(df['speaker_id'][i_new]))&(mean_df['vowel']==df['vowel'][i_new])]
			new_colom_f1[i_new] = df['f1'][i_new]- mean_df_id['f1']
			new_colom_f2[i_new] = df['f2'][i_new]- mean_df_id['f2']
			new_colom_f3[i_new] = df['f3'][i_new]- mean_df_id['f3']
			new_colom_B1[i_new] = df['B1'][i_new]- mean_df_id['B1']
			new_colom_B2[i_new] = df['B2'][i_new]- mean_df_id['B2']
			new_colom_B3[i_new] = df['B3'][i_new]- mean_df_id['B3']

			new_colom_f1_20[i_new] = df['f1@20%'][i_new]- mean_df_id['f1@20%']
			new_colom_f1_35[i_new] = df['f1@35%'][i_new]- mean_df_id['f1@35%']
			new_colom_f1_50[i_new] = df['f1@50%'][i_new]- mean_df_id['f1@50%']
			new_colom_f1_60[i_new] = df['f1@60%'][i_new]- mean_df_id['f1@60%']
			new_colom_f1_80[i_new] = df['f1@80%'][i_new]- mean_df_id['f1@80%']
			new_colom_f2_20[i_new] = df['f2@20%'][i_new]- mean_df_id['f2@20%']
			new_colom_f2_35[i_new] = df['f2@35%'][i_new]- mean_df_id['f2@35%']
			new_colom_f2_50[i_new] = df['f2@50%'][i_new]- mean_df_id['f2@50%']
			new_colom_f2_60[i_new] = df['f2@60%'][i_new]- mean_df_id['f2@60%']
			new_colom_f2_80[i_new] = df['f2@80%'][i_new]- mean_df_id['f2@80%']

		# add new column
		df['f1_c'] = new_colom_f1
		df['f2_c'] = new_colom_f2
		df['f3_c'] = new_colom_f3
		df['B1_c'] = new_colom_B1
		df['B2_c'] = new_colom_B2
		df['B3_c'] = new_colom_B3

		df['f1@20%_c'] = new_colom_f1_20
		df['f1@35%_c'] = new_colom_f1_35
		df['f1@50%_c'] = new_colom_f1_50
		df['f1@60%_c'] = new_colom_f1_60
		df['f1@80%_c'] = new_colom_f1_80
		df['f2@20%_c'] = new_colom_f2_20
		df['f2@35%_c'] = new_colom_f2_35
		df['f2@50%_c'] = new_colom_f2_50
		df['f2@60%_c'] = new_colom_f2_60
		df['f2@80%_c'] = new_colom_f2_80
		# save or add these column into the audio_feature.csv file
		if not os.path.isfile('audio_feature_'+myYear+'.csv'):
			df.to_csv('audio_feature_'+myYear+'.csv',header ='column_names',index = False)
		else:
			df.to_csv('audio_feature_'+myYear+'.csv',mode = 'a',header=False,index = False)
	print "total number of words: ",row_num
	print "For male: ",number_m,gender_word_male
	print "percentage for label as male:",number_m/row_num
	print "For female: ",number_w,gender_word_female
	print "percentage for label as female:",number_w/row_num
	print ""
	return

# %%
root_path = "./"#dropbox address
myYear="2011"
get_start(root_path)
# Out:
# ./oyez_full/fullTierName_2011.csv
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1001.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# total number of words:  29864
# For male:  195.0 {'COUNT': 2, 'HIM': 57, 'HE': 136}
# percentage for label as male: 0.00652960085722
# For female:  36.0 {'SHE': 36}
# percentage for label as female: 0.00120546477364
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1018.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# Finished 31000 rows
# Finished 32000 rows
# Finished 33000 rows
# Finished 34000 rows
# total number of words:  34573
# For male:  341.0 {'BUCK': 2, 'MAYOR': 4, 'HIM': 44, 'ACTOR': 4, 'HE': 287}
# percentage for label as male: 0.00986318803691
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1024.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# Finished 31000 rows
# Finished 32000 rows
# total number of words:  32981
# For male:  93.0 {'HIM': 6, 'HE': 87}
# percentage for label as male: 0.00281980534247
# For female:  18.0 {'DOE': 18}
# percentage for label as female: 0.000545768775962
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1062.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# Finished 31000 rows
# total number of words:  31420
# For male:  2.0 {'HE': 2}
# percentage for label as male: 6.36537237428e-05
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1104.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# total number of words:  30371
# For male:  71.0 {'HIM': 14, 'ACTOR': 4, 'HE': 53}
# percentage for label as male: 0.00233775641237
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1121.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# total number of words:  30939
# For male:  7.0 {'SIR': 3, 'HE': 4}
# percentage for label as male: 0.000226251656485
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 9.69649956366e-05
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1261.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# total number of words:  26691
# For male:  39.0 {'SIR': 6, 'HE': 33}
# percentage for label as male: 0.0014611666854
# For female:  5.0 {'SHE': 5}
# percentage for label as female: 0.000187329062231
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1265.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# Finished 31000 rows
# total number of words:  31551
# For male:  191.0 {'MAN': 2, 'HIM': 10, 'HE': 179}
# percentage for label as male: 0.00605369084974
# For female:  6.0 {'WOMAN': 2, 'SHE': 4}
# percentage for label as female: 0.000190168298945
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1293.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# total number of words:  29883
# For male:  6.0 {'BROTHER': 2, 'STEER': 2, 'HE': 2}
# percentage for label as male: 0.00020078305391
# For female:  24.0 {'SISTER': 4, 'WOMAN': 16, 'FEMALE': 4}
# percentage for label as female: 0.000803132215641
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1320.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# total number of words:  28096
# For male:  109.0 {'COUNT': 27, 'FOREMAN': 8, 'HIM': 7, 'LORD': 2, 'PRINCE': 2, 'HE': 63}
# percentage for label as male: 0.00387955580866
# For female:  27.0 {'SHE': 27}
# percentage for label as female: 0.000960990888383
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1399.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# Finished 29000 rows
# Finished 30000 rows
# Finished 31000 rows
# total number of words:  31572
# For male:  74.0 {'HIM': 9, 'HE': 65}
# percentage for label as male: 0.00234384898011
# For female:  5.0 {'WIFE': 5}
# percentage for label as female: 0.000158368174332
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1472.csv
# Finished 1000 rows
# Finished 2000 rows
# Finished 3000 rows
# Finished 4000 rows
# Finished 5000 rows
# Finished 6000 rows
# Finished 7000 rows
# Finished 8000 rows
# Finished 9000 rows
# Finished 10000 rows
# Finished 11000 rows
# Finished 12000 rows
# Finished 13000 rows
# Finished 14000 rows
# Finished 15000 rows
# Finished 16000 rows
# Finished 17000 rows
# Finished 18000 rows
# Finished 19000 rows
# Finished 20000 rows
# Finished 21000 rows
# Finished 22000 rows
# Finished 23000 rows
# Finished 24000 rows
# Finished 25000 rows
# Finished 26000 rows
# Finished 27000 rows
# Finished 28000 rows
# total number of words:  28312
# For male:  9.0 {'HE': 9}
# percentage for label as male: 0.00031788640859
# For female:  4.0 {'MADAM': 2, 'LADY': 2}
# percentage for label as female: 0.000141282848262
#
# ./FAVE/FAVE-extract/2011_vowels/ABA/2011_10_1491.csv
# Finished 1000 rows
# Finished 2000 rows
