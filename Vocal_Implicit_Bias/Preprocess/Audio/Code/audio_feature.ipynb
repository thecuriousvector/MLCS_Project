# %%
import pandas as pd
import numpy as np
import os.path
from nltk.tag.perceptron import PerceptronTagger

# %%
import nltk
#nltk.download_shell()
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/hiteshochani/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Get the gender of a word: male (1) or female (-1)

# %%
lists_path = '../Lists/'
'''
A dictionary that stores the one-on-one correspondence between 321 gender specific
words/phrases and whether they indicate male or female. 1 stands for male and -1 stands for
female. The classification of the gender specific worsd are from the following three lists:

1. Gender in English: Masculine and Feminine Words, ilu English:
http://www.iluenglish.com/gender-in-english-masculine-and-feminine-words/

2. Stjerneskinn.com: http://stjerneskinn.com/gender-neutral-words.htm

3. EXAMPLES OF GENDER-SENSITIVE LANGUAGE: 
http://www.servicegrowth.net/documents/Examples%20of%20Gender-Sensitive%20Language.net.pdf
'''

'''
Read words from two lists, separately a list of male words and a list of female words -
female_list and a list of male words - male_list. For a word in male_list, the value
associated with it in the dictionary is 1 and for a word in female_list, the value
associated in the dictionary is -1.
'''
gender_dictionary = {}
male_list = open(lists_path+'male_list.txt', 'r')
female_list = open(lists_path+'female_list.txt', 'r')

for word in male_list:
    male_key = word.rstrip('\n')
    gender_dictionary[male_key] = 1

for word in female_list:
    female_key = word.rstrip('\n')
    gender_dictionary[female_key] = -1

male_list.close()
female_list.close()

# %%
def G(word):
    '''
    A function that accepts a string as an argument and returns the gender associated with 
    the string.

    Args
    ----
    word - a str

    Returns
    -------
    1  - if the word is in gender_dictionary and gender_dictionary[word] = 1
    -1 - if the word is in gender_dictionary and gender_dictioanry[word] = -1
    0  - if the word is not in gender_dictionary
    '''
    return gender_dictionary.get(word, 0)

# %%
def get_audio_feature(path,year,filename,whole_list):
    # for ABA format
    # path indicate the root direction for the whole data
    # filename represents .csv file for aba
    # return an n*23 matrix contains speaker infomation, audio features and classify
    audio_matrix = np.empty((0,23))
    aba_table_info = pd.read_csv(data_dir+"ABA/aba_table_info.csv")
    filepath = path+"FAVE/FAVE-extract/"+str(year)+"_vowels/ABA/"+str(filename)+".csv"
    #print path+"FAVE/FAVE-extract/"+str(year)+"_vowels/ABA/"+str(filename)+".csv"
    if os.path.isfile(filepath)==False:
        print("File path invalid ");
        return
    else:
        print (path+"FAVE/FAVE-extract/"+str(year)+"_vowels/ABA/"+str(filename)+".csv")
    feature_list = pd.read_csv(path+"FAVE/FAVE-extract/"+str(year)+"_vowels/ABA/"+str(filename)+".csv")
    row_num = feature_list.shape[0]#all word extracted from the get_audio_feature
    if row_num == 0:
        return
    #fpr de-mean purpose
    id_tmp = 0
    docket_id = 0
    # Create an empty dataframe
    df = pd.DataFrame()

    index = 0.0
    number_m = 0.0;
    gender_word_male = {};
    number_w = 0.0;
    gender_word_female = {};
    counter2=0;
    while (index < row_num):
        counter2+=1
        if(counter2%1000 == 0):
            print("Completed reading rows"+str(counter2))
        speak_a_id = feature_list["speakerA1_id"][index]#speaker A correspond to aba_table_info.csv
        speak_b_id = feature_list["speakerB_id"][index]#speaker B
        tier_num = feature_list["tiernum"][index]#decide who is speaking, correspond to textgrid file
        dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
        speaker_pattern = []
        if len(dt_row) > 0:
            speaker = whole_list["TierName"][dt_row].tolist()
            speakers = speaker[0].split(" ")
            for s in speakers:
                s_tmp = list(s)
                s_tmp[0] = s_tmp[0].upper()
                s = "".join(s_tmp)
                speaker_pattern.append(s)

        pattern = "|".join(speaker_pattern)
        text = feature_list["word"][index]#text, specific words
        pretrain = PerceptronTagger()
        identity_for_text = pretrain.tag([text])
        #filter
        if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):
            classify = G(text.lower());
            if classify == 1:
                value = gender_word_male.get(text, -1)
                if value != -1:
                    gender_word_male[text] += 1
                else:
                    gender_word_male[text] = 1
                number_m += 1
            if classify == -1:
                value = gender_word_female.get(text, -1)
                if value!=-1:
                    gender_word_female[text] += 1
                else:
                    gender_word_female[text] = 1
                number_w += 1

            text_feature_f1 = feature_list["F1"][index]
            text_feature_f2 = feature_list["F2"][index]
            text_feature_f3 = feature_list["F3"][index]
            text_feature_B1 = feature_list["B1"][index]
            text_feature_B2 = feature_list["B2"][index]
            text_feature_B3 = feature_list["B3"][index]
            text_feature_t = feature_list["t"][index]
            text_feature_beg = feature_list["beg"][index]
            text_feature_end = feature_list["end"][index]
            text_feature_dur = feature_list["dur"][index]
            text_feature_F120 = feature_list["F1@20%"][index]
            text_feature_F220 = feature_list["F2@20%"][index]
            text_feature_F135 = feature_list["F1@35%"][index]
            text_feature_F235 = feature_list["F2@35%"][index]
            text_feature_F150 = feature_list["F1@50%"][index]
            text_feature_F250 = feature_list["F2@50%"][index]
            text_feature_F160 = feature_list["F1@65%"][index]
            text_feature_F260 = feature_list["F2@65%"][index]
            text_feature_F180 = feature_list["F1@80%"][index]
            text_feature_F280 = feature_list["F2@80%"][index]

            dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&(aba_table_info["speakerA"].str.contains(pattern,na=False))].index
            dt_row_2 = dt_row_tmp.tolist()
            if len(dt_row_2) != 0:
                #find speaker id
                #save validated data
                speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
                tmp_data = np.array([filename,speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
                    text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
                    text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
                    text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify,identity_for_text[0][1],text]).reshape(1,25)
                test_data_tmp = pd.DataFrame(tmp_data,columns=['docket_id','speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
                    'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify', 'identity','text'])
                test_data_tmp[['f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%']] = test_data_tmp[['f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%']].apply(pd.to_numeric,errors='coerce')
                df = df.append(test_data_tmp,ignore_index=True)
            #print tmp_data.shape
            #audio_matrix = np.append(audio_matrix,tmp_data,axis = 0)
        index += 1
    #deal with the last person in this speech
    # de-mean
    id_tmp = 0
    docket_id_tmp = 0
    if df.shape[0]!=0:
    # not empty
    # define new column
        new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        
        demean = lambda df: df - df.mean() 
        df_group=df.groupby(['speaker_id']).transform(demean)  
        print(df_group.shape)
        print(df.shape)
        print(df_group['f1@20%'])
        #df_group=df.groupby(['speaker_id']).mean()
        df['f1@20%_c'] = df_group['f1@20%']
        df['f1@35%_c'] = df_group['f1@35%']
        df['f1@50%_c'] = df_group['f1@50%']
        df['f1@60%_c'] = df_group['f1@60%']
        df['f1@80%_c'] = df_group['f1@80%']
        df['f2@20%_c'] = df_group['f2@20%']
        df['f2@35%_c'] = df_group['f2@35%']
        df['f2@50%_c'] = df_group['f2@50%']
        df['f2@60%_c'] = df_group['f2@60%']
        df['f2@80%_c'] = df_group['f2@80%']
        
        #for i_new in range(df.shape[0]):
        #    #https://stackoverflow.com/questions/30328646/python-pandas-group-by-in-group-by-and-average
        #    
        #    df_group = df[(df['speaker_id']==df['speaker_id'][i_new])].mean()
        #    print(df_group.values[0])
        #    print "Find column: ", df['f1@20%']
        #    print "Mean: ",df[(df['speaker_id'] == df['speaker_id'][i_new])&(df['docket_id']==df['docket_id'][i_new])]["f1@20%"].mean()
        #    new_colom_f1_20[i_new] = df['f1@20%'][i_new]- df_group['f1@20%']
        #    new_colom_f1_35[i_new] = df['f1@35%'][i_new]- df_group['f1@35%']
        #    new_colom_f1_50[i_new] = df['f1@50%'][i_new]- df_group['f1@50%']
        #    new_colom_f1_60[i_new] = df['f1@60%'][i_new]- df_group['f1@60%']
        #    new_colom_f1_80[i_new] = df['f1@80%'][i_new]- df_group['f1@80%']
        #    new_colom_f2_20[i_new] = df['f2@20%'][i_new]- df_group['f2@20%']
        #    new_colom_f2_35[i_new] = df['f2@35%'][i_new]- df_group['f2@35%']
        #    new_colom_f2_50[i_new] = df['f2@50%'][i_new]- df_group['f2@50%']
        #    new_colom_f2_60[i_new] = df['f2@60%'][i_new]- df_group['f2@60%']
        #    new_colom_f2_80[i_new] = df['f2@80%'][i_new]- df_group['f2@80%']

        # add new column
        #df['f1@20%_c'] = new_colom_f1_20
        #df['f1@35%_c'] = new_colom_f1_35
        #df['f1@50%_c'] = new_colom_f1_50
        #df['f1@60%_c'] = new_colom_f1_60
        #df['f1@80%_c'] = new_colom_f1_80
        #df['f2@20%_c'] = new_colom_f2_20
        #df['f2@35%_c'] = new_colom_f2_35
        #df['f2@50%_c'] = new_colom_f2_50
        #df['f2@60%_c'] = new_colom_f2_60
        #df['f2@80%_c'] = new_colom_f2_80
        # save or add these column into the audio_feature.csv file
        
        #if not os.path.isfile(output_dir+'audio_feature.csv'):
        if not os.path.isfile(output_dir+'audio_feature_'+str(year)+'.csv'):
            df.to_csv(output_dir+'audio_feature_'+str(year)+'.csv',header ='column_names',index = False)
        else:
            df.to_csv(output_dir+'audio_feature_'+str(year)+'.csv',mode = 'a',header=False,index = False)

    print ("total number of words: ",row_num)
    print ("For male: ",number_m,gender_word_male)
    print ("percentage for label as male:",number_m/row_num)
    print ("For female: ",number_w,gender_word_female)
    print ("percentage for label as female:",number_w/row_num)
    print ("")
    return

# %%
def get_start(path):
    whole_list = pd.read_csv(path+"oyez_full/fullTierName_2012.csv")
    #start point
    index = 0
    #row_num = whole_list.shape[0]
    row_num = whole_list.shape[0]
    tmp = 1
    text_grid = 0#text_grid for
    year = 0
    tier_dictionary={}
    counter1=1
    while(index < row_num):
        print("Counter1 is "+str(counter1)+"\n")
        counter1+=1;
        if whole_list["useable"][index]==1:
            #indicate a new file
            if tmp != whole_list["TextGrid"][index]:
                tmp = whole_list["TextGrid"][index]
                year = whole_list["Year"][index]
                get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
        index += 1

# %%
data_dir = '../Data/Inputs/'
output_dir = '/Users/hiteshochani/ml_project/MLCS_Project-master/Vocal_Implicit_Bias/Preprocess/Audio/Data/Outputs/'
get_start(data_dir)
# Out:
# Counter1 is 1
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_10189.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# (20181, 10)
# (20181, 25)
# 0        -90.435163
# 1        -89.835163
# 2       -133.335163
# 3        156.164837
# 4        -59.635163
# 5        -65.535163
# 6        -42.035163
# 7        114.364837
# 8        -77.635163
# 9         23.164837
# 10       -96.635163
# 11       -85.535163
# 12      -109.535163
# 13       -88.935163
# 14       189.364837
# 15       162.164837
# 16        10.864837
# 17       -49.735163
# 18      -216.835163
# 19      -124.135163
# 20       -65.435163
# 21        93.064837
# 22      -114.435163
# 23       -54.035163
# 24       147.764837
# 25       -76.835163
# 26         2.464837
# 27      -116.835163
# 28      -119.135163
# 29      -155.335163
#             ...
# 20151    -96.035163
# 20152    -17.035163
# 20153   -134.035163
# 20154    169.564837
# 20155    -10.735163
# 20156    -94.235163
# 20157   -145.235163
# 20158    -98.135163
# 20159   -144.735163
# 20160    -59.635163
# 20161    -29.235163
# 20162    -64.335163
# 20163   -108.335163
# 20164   -107.735163
# 20165   -104.335163
# 20166   -180.935163
# 20167    -11.035163
# 20168   -143.735163
# 20169   -130.835163
# 20170    -39.335163
# 20171     -7.135163
# 20172     14.164837
# 20173    -26.635163
# 20174     50.264837
# 20175   -125.535163
# 20176   -105.735163
# 20177   -130.435163
# 20178    103.864837
# 20179     24.464837
# 20180     19.664837
# Name: f1@20%, Length: 20181, dtype: float64
# ('total number of words: ', 28152)
# ('For male: ', 71.0, {'HIM': 6, 'HE': 65})
# ('percentage for label as male:', 0.002522023302074453)
# ('For female: ', 10.0, {'SHE': 10})
# ('percentage for label as female:', 0.0003552145495879511)
#
# Counter1 is 2
#
# Counter1 is 3
#
# Counter1 is 4
#
# Counter1 is 5
#
# Counter1 is 6
#
# Counter1 is 7
#
# Counter1 is 8
#
# Counter1 is 9
#
# Counter1 is 10
#
# Counter1 is 11
#
# File path invalid
# Counter1 is 12
#
# Counter1 is 13
#
# Counter1 is 14
#
# Counter1 is 15
#
# Counter1 is 16
#
# Counter1 is 17
#
# Counter1 is 18
#
# Counter1 is 19
#
# Counter1 is 20
#
# Counter1 is 21
#
# File path invalid
# Counter1 is 22
#
# Counter1 is 23
#
# Counter1 is 24
#
# Counter1 is 25
#
# Counter1 is 26
#
# Counter1 is 27
#
# Counter1 is 28
#
# Counter1 is 29
#
# Counter1 is 30
#
# Counter1 is 31
#
# Counter1 is 32
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1085.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# (15050, 10)
# (15050, 25)
# 0       -110.054158
# 1       -142.554158
# 2         59.745842
# 3       -158.154158
# 4       -109.354158
# 5       -150.354158
# 6        -89.254158
# 7        -83.454158
# 8         55.845842
# 9       -105.354158
# 10      -110.854158
# 11      -113.054158
# 12      -191.554158
# 13      -122.754158
# 14       -22.654158
# 15      -152.254158
# 16      -112.054158
# 17      -114.554158
# 18      -116.054158
# 19      -167.254158
# 20      -114.154158
# 21       -30.054158
# 22      -144.654158
# 23       -92.254158
# 24      -130.454158
# 25      -121.254158
# 26      -139.754158
# 27       120.545842
# 28         4.545842
# 29      -130.854158
#             ...
# 15020     36.147054
# 15021     17.847054
# 15022    -85.652946
# 15023    -59.152946
# 15024    254.747054
# 15025      1.247054
# 15026     -6.652946
# 15027    118.547054
# 15028     35.747054
# 15029   -177.052946
# 15030    -26.652946
# 15031    118.147054
# 15032     30.047054
# 15033     43.847054
# 15034    589.047054
# 15035    146.847054
# 15036     39.347054
# 15037    -42.352946
# 15038     -1.652946
# 15039   -106.152946
# 15040    -51.852946
# 15041    150.447054
# 15042     -4.352946
# 15043     -9.152946
# 15044    328.947054
# 15045    -61.852946
# 15046     40.947054
# 15047     38.647054
# 15048     16.447054
# 15049   -103.452946
# Name: f1@20%, Length: 15050, dtype: float64
# ('total number of words: ', 20497)
# ('For male: ', 8.0, {'HE': 8})
# ('percentage for label as male:', 0.00039030101966141384)
# ('For female: ', 0.0, {})
# ('percentage for label as female:', 0.0)
#
# Counter1 is 33
#
# Counter1 is 34
#
# Counter1 is 35
#
# Counter1 is 36
#
# Counter1 is 37
#
# Counter1 is 38
#
# Counter1 is 39
#
# Counter1 is 40
#
# Counter1 is 41
#
# Counter1 is 42
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1118.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# (14491, 10)
# (14491, 25)
# 0       -114.891778
# 1       -145.491778
# 2       -142.991778
# 3         90.008222
# 4       -127.191778
# 5        -62.191778
# 6       -109.591778
# 7        347.808222
# 8         -8.291778
# 9        -73.691778
# 10       -49.391778
# 11       -24.691778
# 12       -90.491778
# 13         9.108222
# 14       115.708222
# 15       132.508222
# 16        85.608222
# 17       377.708222
# 18        33.808222
# 19       -77.291778
# 20      -140.091778
# 21      -135.691778
# 22       -96.891778
# 23      -167.791778
# 24      -146.891778
# 25       121.108222
# 26        31.308222
# 27         2.308222
# 28      -112.491778
# 29      -170.291778
#             ...
# 14461     54.208222
# 14462   -100.791778
# 14463    -79.191778
# 14464    -52.291778
# 14465    -70.891778
# 14466    -97.291778
# 14467   -115.291778
# 14468    -59.391778
# 14469    517.808222
# 14470   -104.491778
# 14471    -16.491778
# 14472   -205.291778
# 14473   -141.191778
# 14474   -149.891778
# 14475   -147.991778
# 14476   -112.691778
# 14477    -94.191778
# 14478   -216.191778
# 14479    507.408222
# 14480   -194.591778
# 14481     -6.791778
# 14482     91.565032
# 14483   -147.134968
# 14484     20.965032
# 14485    -36.534968
# 14486    -44.134968
# 14487   -119.734968
# 14488    -90.834968
# 14489    -73.134968
# 14490    -71.634968
# Name: f1@20%, Length: 14491, dtype: float64
# ('total number of words: ', 29959)
# ('For male: ', 20.0, {'HIM': 7, 'HE': 13})
# ('percentage for label as male:', 0.000667579024667045)
# ('For female: ', 10.0, {'SHE': 10})
# ('percentage for label as female:', 0.0003337895123335225)
#
# Counter1 is 43
#
# Counter1 is 44
#
# Counter1 is 45
#
# Counter1 is 46
#
# Counter1 is 47
#
# Counter1 is 48
#
# Counter1 is 49
#
# Counter1 is 50
#
# Counter1 is 51
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1160.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# (11289, 10)
# (11289, 25)
# 0         16.432147
# 1        -99.167853
# 2        106.932147
# 3         21.732147
# 4       -125.567853
# 5        -11.667853
# 6        -72.667853
# 7       -161.867853
# 8        534.232147
# 9          4.432147
# 10        85.032147
# 11       -44.067853
# 12       140.532147
# 13       352.532147
# 14        -2.367853
# 15        35.632147
# 16       171.532147
# 17       -19.767853
# 18        22.632147
# 19       -40.067853
# 20       -79.867853
# 21         9.032147
# 22        18.232147
# 23        -8.567853
# 24        67.932147
# 25        67.932147
# 26       588.832147
# 27        -3.267853
# 28        43.232147
# 29        50.732147
#             ...
# 11259    -47.022828
# 11260    -65.722828
# 11261   -174.622828
# 11262   -121.422828
# 11263    -82.422828
# 11264   -146.822828
# 11265   -102.122828
# 11266      8.677172
# 11267     33.977172
# 11268    109.877172
# 11269    -10.522828
# 11270    -52.622828
# 11271    -38.522828
# 11272     -0.222828
# 11273    -87.222828
# 11274    153.732147
# 11275    -71.567853
# 11276    124.832147
# 11277    -13.367853
# 11278     32.732147
# 11279    -78.167853
# 11280    -34.567853
# 11281     20.232147
# 11282    -82.867853
# 11283    -72.567853
# 11284    -39.667853
# 11285    -28.067853
# 11286   -114.167853
# 11287    -53.667853
# 11288    -86.467853
# Name: f1@20%, Length: 11289, dtype: float64
# ('total number of words: ', 29664)
# ('For male: ', 35.0, {'MAYOR': 6, 'ACTOR': 18, 'HE': 11})
# ('percentage for label as male:', 0.001179881337648328)
# ('For female: ', 0.0, {})
# ('percentage for label as female:', 0.0)
#
# Counter1 is 52
#
# Counter1 is 53
#
# Counter1 is 54
#
# Counter1 is 55
#
# Counter1 is 56
#
# Counter1 is 57
#
# Counter1 is 58
#
# Counter1 is 59
#
# Counter1 is 60
#
# Counter1 is 61
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1175.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# (2167, 10)
# (2167, 25)
# 0      -153.998569
# 1      -128.498569
# 2       286.301431
# 3        67.801431
# 4        -4.998569
# 5       -92.198569
# 6        66.201431
# 7      -155.798569
# 8      -113.898569
# 9      -193.498569
# 10      -78.098569
# 11      -11.898569
# 12       -2.498569
# 13      -63.898569
# 14      -89.498569
# 15      -96.998569
# 16      -58.598569
# 17      224.701431
# 18      278.701431
# 19      -47.698569
# 20      -62.298569
# 21       57.701431
# 22       54.101431
# 23     -141.298569
# 24      123.601431
# 25      -57.598569
# 26      -34.698569
# 27       94.301431
# 28       18.101431
# 29      -56.798569
#            ...
# 2137   -109.898569
# 2138     44.801431
# 2139    -47.498569
# 2140    121.901431
# 2141     39.801431
# 2142    -70.198569
# 2143    -88.198569
# 2144    -22.598569
# 2145    -56.398569
# 2146     79.401431
# 2147    -60.098569
# 2148    -82.098569
# 2149    -46.398569
# 2150    163.101431
# 2151    -98.098569
# 2152    360.601431
# 2153     99.001431
# 2154    -87.698569
# 2155   -102.298569
# 2156      9.301431
# 2157   -107.198569
# 2158     -0.698569
# 2159     -9.898569
# 2160     -4.098569
# 2161   -189.898569
# 2162    -70.798569
# 2163     11.001431
# 2164    -27.098569
# 2165   -129.098569
# 2166    -63.898569
# Name: f1@20%, Length: 2167, dtype: float64
# ('total number of words: ', 3353)
# ('For male: ', 0.0, {})
# ('percentage for label as male:', 0.0)
# ('For female: ', 0.0, {})
# ('percentage for label as female:', 0.0)
#
# Counter1 is 62
#
# Counter1 is 63
#
# Counter1 is 64
#
# Counter1 is 65
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1221.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# (13128, 10)
# (13128, 25)
# 0        -65.28014
# 1       -133.28014
# 2       -169.48014
# 3         65.81986
# 4        -67.98014
# 5         11.61986
# 6         35.31986
# 7        274.21986
# 8        -59.98014
# 9        -69.48014
# 10        88.01986
# 11        48.61986
# 12        -2.18014
# 13       -33.98014
# 14       -95.78014
# 15         4.91986
# 16        83.91986
# 17        -9.38014
# 18        98.71986
# 19       315.71986
# 20       -74.58014
# 21        52.81986
# 22       -17.38014
# 23       -49.28014
# 24       -56.48014
# 25        54.71986
# 26       -23.88014
# 27       -52.38014
# 28       -36.68014
# 29        44.11986
#            ...
# 13098     57.11986
# 13099    236.21986
# 13100    -47.48014
# 13101    -62.48014
# 13102    104.51986
# 13103     94.41986
# 13104    -61.28014
# 13105    134.71986
# 13106    -34.58014
# 13107    -76.58014
# 13108    126.71986
# 13109   -109.38014
# 13110    123.61986
# 13111     13.31986
# 13112    -72.18014
# 13113    -13.88014
# 13114   -104.08014
# 13115     97.51986
# 13116    192.31986
# 13117     86.91986
# 13118    207.21986
# 13119    125.01986
# 13120   -138.78014
# 13121    448.11986
# 13122     19.51986
# 13123     53.71986
# 13124   -134.68014
# 13125    -51.68014
# 13126    -21.48014
# 13127    -83.98014
# Name: f1@20%, Length: 13128, dtype: float64
# ('total number of words: ', 25373)
# ('For male: ', 34.0, {'SON': 2, 'MAN': 3, 'HIM': 2, 'HUSBAND': 12, 'HE': 15})
# ('percentage for label as male:', 0.0013400070941552043)
# ('For female: ', 37.0, {'WIDOW': 6, 'SHE': 5, 'WIFE': 26})
# ('percentage for label as female:', 0.0014582430142277224)
#
# Counter1 is 66
#
# Counter1 is 67
#
# Counter1 is 68
#
# Counter1 is 69
#
# Counter1 is 70
#
# Counter1 is 71
#
# Counter1 is 72
#
# Counter1 is 73
#
# Counter1 is 74
#
# Counter1 is 75
#
# Counter1 is 76
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1274.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# (19906, 10)
# (19906, 25)
# 0         -79.014300
# 1         -98.214300
# 2        -105.814300
# 3         193.585700
# 4         -84.514300
# 5        -105.814300
# 6          41.185700
# 7        -108.614300
# 8          16.485700
# 9         -76.814300
# 10        -25.014300
# 11        152.485700
# 12       -165.814300
# 13       1484.885700
# 14       -135.514300
# 15          2.185700
# 16       -115.714300
# 17        -63.814300
# 18         78.885700
# 19        -91.714300
# 20        144.085700
# 21        -55.614300
# 22       -160.914300
# 23          3.285700
# 24        168.185700
# 25        135.685700
# 26         56.485700
# 27        -15.214300
# 28        -70.314300
# 29         -4.214300
#             ...
# 19876     -16.614300
# 19877    -107.514300
# 19878     -65.314300
# 19879     -89.614300
# 19880    -138.414300
# 19881     238.985700
# 19882      48.285700
# 19883     -72.114300
# 19884            NaN
# 19885    -173.414300
# 19886     -65.714300
# 19887    -125.814300
# 19888    -113.214300
# 19889     -89.914300
# 19890     -71.414300
# 19891      11.985700
# 19892     214.785700
# 19893     193.685700
# 19894     154.885700
# 19895     195.185700
# 19896    -113.277963
# 19897      70.522037
# 19898     259.722037
# 19899     148.522037
# 19900     -49.077963
# 19901      19.422037
# 19902     -89.177963
# 19903     -86.977963
# 19904     -27.977963
# 19905     -23.477963
# Name: f1@20%, Length: 19906, dtype: float64
# ('total number of words: ', 28424)
# ('For male: ', 16.0, {'COUNT': 2, 'HIM': 3, 'HE': 11})
# ('percentage for label as male:', 0.0005629045876723895)
# ('For female: ', 7.0, {'SHE': 7})
# ('percentage for label as female:', 0.0002462707571066704)
#
# Counter1 is 77
#
# Counter1 is 78
#
# Counter1 is 79
#
# Counter1 is 80
#
# Counter1 is 81
#
# Counter1 is 82
#
# Counter1 is 83
#
# Counter1 is 84
#
# Counter1 is 85
#
# Counter1 is 86
#
# ../Data/Inputs/FAVE/FAVE-extract/2012_vowels/ABA/2012_11_1285.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
