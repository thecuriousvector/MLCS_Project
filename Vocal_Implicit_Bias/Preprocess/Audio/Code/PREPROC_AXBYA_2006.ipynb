# %%
import pandas as pd
import numpy as np
import os.path
#make sure gender_word.py is under the same folder
from nltk.tag.perceptron import PerceptronTagger
import nltk
#nltk.download_shell()
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/richadeshmukh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
gender_dictionary = {}
male_list = open("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/text/male_list.txt", 'r')
female_list = open("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/text/female_list.txt", 'r')

for word in male_list:
    male_key = word.rstrip('\n')
    gender_dictionary[male_key] = 1

for word in female_list:
    female_key = word.rstrip('\n')
    gender_dictionary[female_key] = -1

male_list.close()
female_list.close()

def G(word):
    '''
    A function that accepts a string as an argument and returns the gender associated with 
    the string.

    Args
    ----
    word - a str

    Returns
    -------
    1  - if the word is in gender_dictionary and gender_dictionary[word] = 1
    -1 - if the word is in gender_dictionary and gender_dictioanry[word] = -1
    0  - if the word is not in gender_dictionary
    '''
    return gender_dictionary.get(word, 0)

# %%
def get_start(path):

    print "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2006.csv"
    whole_list = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2006.csv")
    
    #start point & end point
    index = 0
    row_num = whole_list.shape[0]
    tmp = 0

    #log file
    if os.path.isfile('log_2006.bin'):
        with open("log_2006.bin","r") as log_file:
            log_content = log_file.readlines()[0].split(" ")
            if len(log_content)>0:
                index = int(log_content[-2])
                tmp = whole_list["TextGrid"][index]
                print ("Start from ",tmp)
            else:
                print ("log file is empty")
    else:
        print ("File doesn't exist.")
        print ("Start from begining")


    with open("log_2006.bin","a+") as log_file: 
        #go through every row in index file and record log
        counter1=1
        while(index < row_num):
            print("Counter1 is "+str(counter1)+"\n")
            if whole_list["useable"][index]==1:
                if tmp != whole_list["TextGrid"][index]:
                    log_file.write(str(index)+" ")
                    log_file.flush()
                    tmp = whole_list["TextGrid"][index]
                    year = whole_list["Year"][index]
                    get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
            index += 1

# %%
def get_audio_feature(path,year,filename,whole_list):
    # for ABA format
    # path indicate the root direction for the whole data
    # filename represents .csv file for aba 
    # return an n*23 matrix contains speaker infomation, audio features and classify
    
    aba_table_info = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/axbya_table_info.csv")
    filepath = "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/"+str(filename)+".csv"
    #check exist
    if os.path.isfile(filepath)==False:
        return
    else:
        print "/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/"+str(filename)+".csv"
    feature_list = pd.read_csv("/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/"+str(filename)+".csv")
    row_num = feature_list.shape[0]
    #illegal file
    if row_num == 0:
        return

    df = pd.DataFrame()
    index = 0.0
    number_m = 0.0;
    gender_word_male = {};
    number_w = 0.0;
    gender_word_female = {};
    speaker_id_map = {};
    vowel_id = {};
    pretrain = PerceptronTagger()
    counter2=0;
    while (index < row_num):
        counter2+=1
        if(counter2%1000 == 0):
            print("Completed reading rows"+str(counter2))
        text = feature_list["word"][index]
        identity_for_text = pretrain.tag([text])
        if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):#filter
            # record 
            classify = G(text.lower());
            if classify == 1:
                value = gender_word_male.get(text, -1)
                if value != -1:
                    gender_word_male[text] += 1
                else: 
                    gender_word_male[text] = 1
                number_m += 1
            if classify == -1:
                value = gender_word_female.get(text, -1)
                if value!=-1:
                    gender_word_female[text] += 1
                else:
                    gender_word_female[text] = 1
                number_w += 1

            vowel = feature_list["vowel"][index]#added feature
            value = vowel_id.get(vowel, -1)
            if value == -1:
                vowel_id[vowel] = 1

            #decide who do the speach 
            speak_a_id = feature_list["speakerA1_id"][index]
            speak_b_id = feature_list["speakerB_id"][index]
            speak_x_id = feature_list["speakerY_id"][index]
            speak_y_id = feature_list["speakerX_id"][index]
            tier_num = feature_list["tiernum"][index]
            dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
            speaker_pattern = []
            if len(dt_row) > 0:
                speaker = whole_list["TierName"][dt_row].tolist()
                speakers = speaker[0].split(" ")
                for s in speakers:
                    s_tmp = list(s)
                    s_tmp[0] = s_tmp[0].upper()
                    s = "".join(s_tmp)
                    speaker_pattern.append(s)
            
            pattern = "|".join(speaker_pattern)

            dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&((aba_table_info["speakerA"].str.contains(pattern,na=False))|
                (aba_table_info["speakerB"].str.contains(pattern,na=False))|(aba_table_info["speakerX"].str.contains(pattern,na=False))|
                (aba_table_info["speakerY"].str.contains(pattern,na=False)))].index
            dt_row_2 = dt_row_tmp.tolist()
            if len(dt_row_2) != 0:
                speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
                value = speaker_id_map.get(speaker_id, -1)
                if value == -1:
                    speaker_id_map[speaker_id] = 1
                
                text_feature_f1 = feature_list["F1"][index]
                text_feature_f2 = feature_list["F2"][index]
                text_feature_f3 = feature_list["F3"][index]
                text_feature_B1 = feature_list["B1"][index]
                text_feature_B2 = feature_list["B2"][index]
                text_feature_B3 = feature_list["B3"][index]
                text_feature_t = feature_list["t"][index]
                text_feature_beg = feature_list["beg"][index]
                text_feature_end = feature_list["end"][index]
                text_feature_dur = feature_list["dur"][index]
                text_feature_F120 = feature_list["F1@20%"][index]
                text_feature_F220 = feature_list["F2@20%"][index]
                text_feature_F135 = feature_list["F1@35%"][index]
                text_feature_F235 = feature_list["F2@35%"][index]
                text_feature_F150 = feature_list["F1@50%"][index]
                text_feature_F250 = feature_list["F2@50%"][index]
                text_feature_F160 = feature_list["F1@65%"][index]
                text_feature_F260 = feature_list["F2@65%"][index]
                text_feature_F180 = feature_list["F1@80%"][index]
                text_feature_F280 = feature_list["F2@80%"][index]
                tmp_data = np.array([speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
                    text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
                    text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
                    text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify]).reshape(1,22)
                test_data_tmp = pd.DataFrame(tmp_data,columns=['speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
                    'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify'])
                test_data_tmp['docket_id'] = filename
                test_data_tmp['identity'] = identity_for_text[0][1]
                test_data_tmp['text'] = text
                test_data_tmp['vowel'] = vowel
                df = df.append(test_data_tmp,ignore_index=True)
        index += 1

    # extract mean
    mean_df = pd.DataFrame()
    for key in speaker_id_map:
        for key_2 in vowel_id:
            df_tmp = df[(df['speaker_id']==key)&(df['vowel']==key_2)].mean()
            df_tmp['speaker_id'] = key;
            df_tmp['vowel'] = key_2
            mean_df = mean_df.append(df_tmp,ignore_index=True)
    if df.shape[0]!=0:

        new_colom_f1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f3 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B3 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        for i_new in range(df.shape[0]):
            mean_df_id = mean_df[(mean_df['speaker_id']==float(df['speaker_id'][i_new]))&(mean_df['vowel']==df['vowel'][i_new])]
            new_colom_f1[i_new] = df['f1'][i_new]- mean_df_id['f1']
            new_colom_f2[i_new] = df['f2'][i_new]- mean_df_id['f2']
            new_colom_f3[i_new] = df['f3'][i_new]- mean_df_id['f3']
            new_colom_B1[i_new] = df['B1'][i_new]- mean_df_id['B1']
            new_colom_B2[i_new] = df['B2'][i_new]- mean_df_id['B2']
            new_colom_B3[i_new] = df['B3'][i_new]- mean_df_id['B3']

            new_colom_f1_20[i_new] = df['f1@20%'][i_new]- mean_df_id['f1@20%']
            new_colom_f1_35[i_new] = df['f1@35%'][i_new]- mean_df_id['f1@35%']
            new_colom_f1_50[i_new] = df['f1@50%'][i_new]- mean_df_id['f1@50%']
            new_colom_f1_60[i_new] = df['f1@60%'][i_new]- mean_df_id['f1@60%']
            new_colom_f1_80[i_new] = df['f1@80%'][i_new]- mean_df_id['f1@80%']
            new_colom_f2_20[i_new] = df['f2@20%'][i_new]- mean_df_id['f2@20%']
            new_colom_f2_35[i_new] = df['f2@35%'][i_new]- mean_df_id['f2@35%']
            new_colom_f2_50[i_new] = df['f2@50%'][i_new]- mean_df_id['f2@50%']
            new_colom_f2_60[i_new] = df['f2@60%'][i_new]- mean_df_id['f2@60%']
            new_colom_f2_80[i_new] = df['f2@80%'][i_new]- mean_df_id['f2@80%']

        # add new column
        df['f1_c'] = new_colom_f1
        df['f2_c'] = new_colom_f2
        df['f3_c'] = new_colom_f3
        df['B1_c'] = new_colom_B1
        df['B2_c'] = new_colom_B2
        df['B3_c'] = new_colom_B3

        df['f1@20%_c'] = new_colom_f1_20
        df['f1@35%_c'] = new_colom_f1_35
        df['f1@50%_c'] = new_colom_f1_50
        df['f1@60%_c'] = new_colom_f1_60
        df['f1@80%_c'] = new_colom_f1_80
        df['f2@20%_c'] = new_colom_f2_20
        df['f2@35%_c'] = new_colom_f2_35
        df['f2@50%_c'] = new_colom_f2_50
        df['f2@60%_c'] = new_colom_f2_60
        df['f2@80%_c'] = new_colom_f2_80
        # save or add these column into the audio_feature.csv file
        if not os.path.isfile('audio_feature_axbya_2006.csv'):
            df.to_csv('audio_feature_axbya_2006.csv',header ='column_names',index = False)
        else:
            df.to_csv('audio_feature_axbya_2006.csv',mode = 'a',header=False,index = False)
    
    print "total number of words: ",row_num
    print "For male: ",number_m,gender_word_male
    print "percentage for label as male:",number_m/row_num
    print "For female: ",number_w,gender_word_female
    print "percentage for label as female:",number_w/row_num
    print ""
    return

# %%
data_dir = '/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/'
output_dir = '/Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/'
get_start(data_dir)
# Out:
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2006.csv
# ('Start from ', '2006_05_1074.TextGrid')
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1126.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# total number of words:  11132
# For male:  9.0 {'HE': 9}
# percentage for label as male: 0.000808480057492
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_11284.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# total number of words:  13729
# For male:  127.0 {'MAN': 6, 'FATHER': 20, 'HIM': 25, 'HE': 76}
# percentage for label as male: 0.00925049165999
# For female:  16.0 {'MOTHER': 16}
# percentage for label as female: 0.00116541627212
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_11304.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10331
# For male:  36.0 {'MAN': 2, 'FATHER': 2, 'HIM': 6, 'HE': 26}
# percentage for label as male: 0.00348465782596
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1240.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# total number of words:  6872
# For male:  45.0 {'MAN': 1, 'HIM': 9, 'HE': 35}
# percentage for label as male: 0.00654831199069
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1256.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# total number of words:  6755
# For male:  18.0 {'MASTER': 4, 'HIM': 3, 'HE': 11}
# percentage for label as male: 0.00266469282013
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1272.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# total number of words:  15454
# For male:  116.0 {'HIM': 3, 'HE': 113}
# percentage for label as male: 0.00750614727579
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1284.csv
# /Users/richadeshmukh/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8200
# For male:  27.0 {'CHAIRMAN': 16, 'ACTOR': 2, 'HE': 9}
# percentage for label as male: 0.00329268292683
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1342.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8694
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1345.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8466
# For male:  1.0 {'COUNT': 1}
# percentage for label as male: 0.000118119536971
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1382.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5013
# For male:  3.0 {'HE': 3}
# percentage for label as male: 0.000598444045482
# For female:  24.0 {'WOMAN': 18, 'SHE': 4, 'MOTHER': 2}
# percentage for label as female: 0.00478755236385
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1508.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# total number of words:  14052
# For male:  18.0 {'GIANT': 8, 'HIM': 1, 'HE': 9}
# percentage for label as male: 0.00128095644748
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1541.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5643
# For male:  7.0 {'HUSBAND': 2, 'HE': 5}
# percentage for label as male: 0.00124047492469
# For female:  6.0 {'WOMAN': 2, 'SHE': 4}
# percentage for label as female: 0.00106326422116
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1629.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5882
# For male:  11.0 {'COUNT': 2, 'HE': 9}
# percentage for label as male: 0.00187011220673
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_1631.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7420
# For male:  122.0 {'RAM': 1, 'HOST': 2, 'HE': 92, 'HIM': 21, 'POLICEMAN': 6}
# percentage for label as male: 0.0164420485175
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_380.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9636
# For male:  8.0 {'HE': 8}
# percentage for label as male: 0.000830220008302
# For female:  22.0 {'WOMAN': 6, 'SHE': 2, 'MOTHER': 14}
# percentage for label as female: 0.00228310502283
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_381.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9677
# For male:  14.0 {'COUNT': 3, 'HIM': 1, 'HE': 10}
# percentage for label as male: 0.00144672935827
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_547.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8469
# For male:  34.0 {'COUNT': 4, 'HIM': 4, 'HE': 26}
# percentage for label as male: 0.0040146416342
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_595.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5344
# For male:  10.0 {'DUKE': 1, 'HE': 3, 'DOG': 1, 'HIM': 2, 'MAN': 3}
# percentage for label as male: 0.00187125748503
# For female:  2.0 {'SHE': 1, 'WIFE': 1}
# percentage for label as female: 0.000374251497006
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_608.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# total number of words:  10628
# For male:  8.0 {'COUNT': 1, 'MASTER': 2, 'HE': 5}
# percentage for label as male: 0.000752728641325
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_6551.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9891
# For male:  36.0 {'FATHER': 2, 'HE': 34}
# percentage for label as male: 0.00363967242948
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_669.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# total number of words:  14667
# For male:  9.0 {'HE': 9}
# percentage for label as male: 0.000613622417672
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_7058.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9393
# For male:  82.0 {'HIM': 4, 'HE': 78}
# percentage for label as male: 0.00872990524859
# For female:  5.0 {'SHE': 5}
# percentage for label as female: 0.000532311295646
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_85.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7705
# For male:  10.0 {'DUKE': 1, 'KING': 2, 'HE': 7}
# percentage for label as male: 0.00129785853342
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_8820.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8158
# For male:  16.0 {'COUNT': 1, 'SIR': 10, 'HE': 5}
# percentage for label as male: 0.00196126501594
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 0.000122579063496
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_9222.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5343
# For male:  54.0 {'HIM': 2, 'BROTHER': 2, 'HE': 50}
# percentage for label as male: 0.0101066816395
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_05_9264.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# total number of words:  9420
# For male:  4.0 {'HE': 4}
# percentage for label as male: 0.000424628450106
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_102.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# total number of words:  4566
# For male:  0.0 {}
# percentage for label as male: 0.0
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_134.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8839
# For male:  16.0 {'HIM': 2, 'HE': 14}
# percentage for label as male: 0.00181015952031
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_157.csv
# total number of words:  162
# For male:  2.0 {'HE': 2}
# percentage for label as male: 0.0123456790123
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_313.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# total number of words:  7960
# For male:  87.0 {'GENTLEMEN': 12, 'COUNT': 1, 'HIM': 11, 'HE': 63}
# percentage for label as male: 0.0109296482412
# For female:  8.0 {'LADIES': 8}
# percentage for label as female: 0.00100502512563
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_484.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# total number of words:  5581
# For male:  26.0 {'HE': 26}
# percentage for label as male: 0.00465866332199
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000537538075614
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_5247.csv
# Completed reading rows1000
# Completed reading rows2000
# total number of words:  2153
# For male:  4.0 {'HIM': 1, 'HE': 3}
# percentage for label as male: 0.00185787273572
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_531.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# total number of words:  6376
# For male:  18.0 {'HIM': 2, 'ACTOR': 4, 'HE': 12}
# percentage for label as male: 0.00282308657465
# For female:  9.0 {'SHE': 9}
# percentage for label as female: 0.00141154328733
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_562.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12717
# For male:  11.0 {'HOST': 1, 'HIM': 1, 'HE': 9}
# percentage for label as male: 0.000864983879846
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_593.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8720
# For male:  6.0 {'UNCLE': 2, 'SON': 1, 'HE': 1, 'MAN': 2}
# percentage for label as male: 0.000688073394495
# For female:  14.0 {'WOMAN': 4, 'DAUGHTER': 2, 'AUNT': 1, 'SHE': 1, 'MOTHER': 2, 'LADY': 4}
# percentage for label as female: 0.00160550458716
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/MLCS_Project/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/AXBYA/2006_06_618.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# total number of words:  8991
# For male:  73.0 {'HIM': 2, 'HE': 71}
# percentage for label as male: 0.00811923034145
# For female:  1.0 {'DOE': 1}
# percentage for label as female: 0.000111222333445
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
