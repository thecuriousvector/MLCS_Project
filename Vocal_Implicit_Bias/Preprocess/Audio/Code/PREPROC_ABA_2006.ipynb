# %%
import pandas as pd
import numpy as np
import os.path
#make sure gender_word.py is under the same folder
from nltk.tag.perceptron import PerceptronTagger
import nltk
#nltk.download_shell()
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/richadeshmukh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
'''
A dictionary that stores the one-on-one correspondence between 321 gender specific
words/phrases and whether they indicate male or female. 1 stands for male and -1 stands for
female. The classification of the gender specific worsd are from the following three lists:

1. Gender in English: Masculine and Feminine Words, ilu English:
http://www.iluenglish.com/gender-in-english-masculine-and-feminine-words/

2. Stjerneskinn.com: http://stjerneskinn.com/gender-neutral-words.htm

3. EXAMPLES OF GENDER-SENSITIVE LANGUAGE: 
http://www.servicegrowth.net/documents/Examples%20of%20Gender-Sensitive%20Language.net.pdf
'''

'''
Read words from two lists, separately a list of male words and a list of female words -
female_list and a list of male words - male_list. For a word in male_list, the value
associated with it in the dictionary is 1 and for a word in female_list, the value
associated in the dictionary is -1.
'''
gender_dictionary = {}
male_list = open("/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/text/male_list.txt", 'r')
female_list = open("/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/text/female_list.txt", 'r')

for word in male_list:
    male_key = word.rstrip('\n')
    gender_dictionary[male_key] = 1

for word in female_list:
    female_key = word.rstrip('\n')
    gender_dictionary[female_key] = -1

male_list.close()
female_list.close()

def G(word):
    '''
    A function that accepts a string as an argument and returns the gender associated with 
    the string.

    Args
    ----
    word - a str

    Returns
    -------
    1  - if the word is in gender_dictionary and gender_dictionary[word] = 1
    -1 - if the word is in gender_dictionary and gender_dictioanry[word] = -1
    0  - if the word is not in gender_dictionary
    '''
    return gender_dictionary.get(word, 0)

# %%
def get_start(path):

    print "/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2006.csv"
    whole_list = pd.read_csv("/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2006.csv")
    
    #start point
    index = 0
    row_num = whole_list.shape[0]
    tmp = 1
    text_grid = 0#text_grid for 
    year = 0
    tier_dictionary={}
    counter1=1
    while(index < row_num):
        print("Counter1 is "+str(counter1)+"\n")
        if whole_list["useable"][index]==1:
            #indicate a new file
            if tmp != whole_list["TextGrid"][index]:
                tmp = whole_list["TextGrid"][index]
                year = whole_list["Year"][index]
                get_audio_feature(path,year,whole_list["TextGrid"][index].split(".")[0],whole_list)
        index += 1

# %%
def get_audio_feature(path,year,filename,whole_list):
    # for ABA format
    # path indicate the root direction for the whole data
    # filename represents .csv file for aba 
    # return an n*23 matrix contains speaker infomation, audio features and classify
    audio_matrix = np.empty((0,23))
    aba_table_info = pd.read_csv("/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/aba_table_info.csv")
    filepath = "/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/"+str(filename)+".csv"
    if os.path.isfile(filepath)==False:
        return
    else:
        print "/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/"+str(filename)+".csv"
    feature_list = pd.read_csv("/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/"+str(filename)+".csv")
    row_num = feature_list.shape[0]#all word extracted from the get_audio_feature
    if row_num == 0:
        return
    #fpr de-mean purpose 
    id_tmp = 0
    docket_id = 0
    # Create an empty dataframe
    df = pd.DataFrame()

    index = 0.0
    number_m = 0.0;
    gender_word_male = {};
    number_w = 0.0;
    gender_word_female = {};
    speaker_id_map = {};
    vowel_id = {};
    counter2=0;
    while (index < row_num):
        counter2+=1
        if(counter2%1000 == 0):
            print("Completed reading rows"+str(counter2))
        speak_a_id = feature_list["speakerA1_id"][index]#speaker A correspond to aba_table_info.csv
        speak_b_id = feature_list["speakerB_id"][index]#speaker B
        tier_num = feature_list["tiernum"][index]#decide who is speaking, correspond to textgrid file
        dt_row = whole_list[(whole_list['TextGrid'] == filename+".TextGrid")&(whole_list["TierNumber"]==tier_num)].index
        speaker_pattern = []
        if len(dt_row) > 0:
            speaker = whole_list["TierName"][dt_row].tolist()
            speakers = speaker[0].split(" ")
            for s in speakers:
                s_tmp = list(s)
                s_tmp[0] = s_tmp[0].upper()
                s = "".join(s_tmp)
                speaker_pattern.append(s)
        
        pattern = "|".join(speaker_pattern)
        text = feature_list["word"][index]#text, specific words
        pretrain = PerceptronTagger()
        identity_for_text = pretrain.tag([text])
        #filter
        if (identity_for_text[0][1]=='NN' or identity_for_text[0][1] =='NNS'):
            classify = G(text.lower());
            if classify == 1:
                value = gender_word_male.get(text, -1)
                if value != -1:
                    gender_word_male[text] += 1
                else: 
                        gender_word_male[text] = 1
                number_m += 1
            if classify == -1:
                value = gender_word_female.get(text, -1)
                if value!=-1:
                    gender_word_female[text] += 1
                else:
                    gender_word_female[text] = 1
                number_w += 1
            vowel = feature_list["vowel"][index]#added feature
            value = vowel_id.get(vowel, -1)
            if value == -1:
                vowel_id[vowel] = 1

            text_feature_f1 = feature_list["F1"][index]
            text_feature_f2 = feature_list["F2"][index]
            text_feature_f3 = feature_list["F3"][index]
            text_feature_B1 = feature_list["B1"][index]
            text_feature_B2 = feature_list["B2"][index]
            text_feature_B3 = feature_list["B3"][index]
            text_feature_t = feature_list["t"][index]
            text_feature_beg = feature_list["beg"][index]
            text_feature_end = feature_list["end"][index]
            text_feature_dur = feature_list["dur"][index]
            text_feature_F120 = feature_list["F1@20%"][index]
            text_feature_F220 = feature_list["F2@20%"][index]
            text_feature_F135 = feature_list["F1@35%"][index]
            text_feature_F235 = feature_list["F2@35%"][index]
            text_feature_F150 = feature_list["F1@50%"][index]
            text_feature_F250 = feature_list["F2@50%"][index]
            text_feature_F160 = feature_list["F1@65%"][index]
            text_feature_F260 = feature_list["F2@65%"][index]
            text_feature_F180 = feature_list["F1@80%"][index]
            text_feature_F280 = feature_list["F2@80%"][index]


            dt_row_tmp = aba_table_info[(aba_table_info["docket_id"]==filename)&(aba_table_info["speakerA"].str.contains(pattern,na=False))].index
            dt_row_2 = dt_row_tmp.tolist()
            if len(dt_row_2) != 0:
                #find speaker id 
                #save validated data
                speaker_id = aba_table_info["speakerA_id"][dt_row_2[0]]
                value = speaker_id_map.get(speaker_id, -1)
                if value == -1:
                    speaker_id_map[speaker_id] = 1
                
                tmp_data = np.array([speaker_id,text_feature_f1,text_feature_f2,text_feature_f3,text_feature_B1,
                    text_feature_B2,text_feature_B3,text_feature_t,text_feature_beg,text_feature_end,text_feature_dur,
                    text_feature_F120,text_feature_F220,text_feature_F135,text_feature_F235,text_feature_F150,text_feature_F250,
                    text_feature_F160,text_feature_F260,text_feature_F180,text_feature_F280,classify]).reshape(1,22)
                test_data_tmp = pd.DataFrame(tmp_data,columns=['speaker_id','f1','f2','f3','B1','B2','B3','t','beg','end','dur',
                    'f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%', 'classify'])
                test_data_tmp['docket_id'] = filename
                test_data_tmp['identity'] = identity_for_text[0][1]
                test_data_tmp['text'] = text
                test_data_tmp['vowel'] = vowel
                #test_data_tmp[['f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%']] = test_data_tmp[['f1@20%','f2@20%','f1@35%','f2@35%','f1@50%','f2@50%','f1@60%','f2@60%','f1@80%','f2@80%']].apply(pd.to_numeric,errors='coerce')
                df = df.append(test_data_tmp,ignore_index=True)
        index += 1
    #deal with the last person in this speech
    # de-mean
    id_tmp = 0
    docket_id_tmp = 0
    # extract mean
    mean_df = pd.DataFrame()
    for key in speaker_id_map:
        for key_2 in vowel_id:
            df_tmp = df[(df['speaker_id']==key)&(df['vowel']==key_2)].mean()
            df_tmp['speaker_id'] = key;
            df_tmp['vowel'] = key_2
            mean_df = mean_df.append(df_tmp,ignore_index=True)
    if df.shape[0]!=0:
    # not empty
    # define new column
        new_colom_f1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f3 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B1 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B2 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_B3 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        new_colom_f1_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f1_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_20 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_35 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_50 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_60 = pd.Series(np.zeros(df.shape[0]), index=df.index)
        new_colom_f2_80 = pd.Series(np.zeros(df.shape[0]), index=df.index)

        for i_new in range(df.shape[0]):
            mean_df_id = mean_df[(mean_df['speaker_id']==float(df['speaker_id'][i_new]))&(mean_df['vowel']==df['vowel'][i_new])]
            new_colom_f1[i_new] = df['f1'][i_new]- mean_df_id['f1']
            new_colom_f2[i_new] = df['f2'][i_new]- mean_df_id['f2']
            new_colom_f3[i_new] = df['f3'][i_new]- mean_df_id['f3']
            new_colom_B1[i_new] = df['B1'][i_new]- mean_df_id['B1']
            new_colom_B2[i_new] = df['B2'][i_new]- mean_df_id['B2']
            new_colom_B3[i_new] = df['B3'][i_new]- mean_df_id['B3']

            new_colom_f1_20[i_new] = df['f1@20%'][i_new]- mean_df_id['f1@20%']
            new_colom_f1_35[i_new] = df['f1@35%'][i_new]- mean_df_id['f1@35%']
            new_colom_f1_50[i_new] = df['f1@50%'][i_new]- mean_df_id['f1@50%']
            new_colom_f1_60[i_new] = df['f1@60%'][i_new]- mean_df_id['f1@60%']
            new_colom_f1_80[i_new] = df['f1@80%'][i_new]- mean_df_id['f1@80%']
            new_colom_f2_20[i_new] = df['f2@20%'][i_new]- mean_df_id['f2@20%']
            new_colom_f2_35[i_new] = df['f2@35%'][i_new]- mean_df_id['f2@35%']
            new_colom_f2_50[i_new] = df['f2@50%'][i_new]- mean_df_id['f2@50%']
            new_colom_f2_60[i_new] = df['f2@60%'][i_new]- mean_df_id['f2@60%']
            new_colom_f2_80[i_new] = df['f2@80%'][i_new]- mean_df_id['f2@80%']

        # add new column
        df['f1_c'] = new_colom_f1
        df['f2_c'] = new_colom_f2
        df['f3_c'] = new_colom_f3
        df['B1_c'] = new_colom_B1
        df['B2_c'] = new_colom_B2
        df['B3_c'] = new_colom_B3

        df['f1@20%_c'] = new_colom_f1_20
        df['f1@35%_c'] = new_colom_f1_35
        df['f1@50%_c'] = new_colom_f1_50
        df['f1@60%_c'] = new_colom_f1_60
        df['f1@80%_c'] = new_colom_f1_80
        df['f2@20%_c'] = new_colom_f2_20
        df['f2@35%_c'] = new_colom_f2_35
        df['f2@50%_c'] = new_colom_f2_50
        df['f2@60%_c'] = new_colom_f2_60
        df['f2@80%_c'] = new_colom_f2_80
        # save or add these column into the audio_feature.csv file
        if not os.path.isfile('audio_feature_2006.csv'):
            df.to_csv('audio_feature_2006.csv',header ='column_names',index = False)
        else:
            df.to_csv('audio_feature_2006.csv',mode = 'a',header=False,index = False)
    print "total number of words: ",row_num
    print "For male: ",number_m,gender_word_male
    print "percentage for label as male:",number_m/row_num
    print "For female: ",number_w,gender_word_female
    print "percentage for label as female:",number_w/row_num
    print ""
    return

# %%
data_dir = '/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/'
output_dir = '/Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/outputs/'
get_start(data_dir)
# Out:
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/Dropbox/oyez_full/fullTierName_2006.csv
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1056.csv
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1074.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# Completed reading rows32000
# total number of words:  32359
# For male:  78.0 {'MAN': 5, 'MALE': 15, 'HE': 58}
# percentage for label as male: 0.00241045767793
# For female:  166.0 {'WOMAN': 34, 'SHE': 102, 'FEMALE': 30}
# percentage for label as female: 0.00512994839148
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1126.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29238
# For male:  13.0 {'HE': 13}
# percentage for label as male: 0.000444626855462
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_11284.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29512
# For male:  243.0 {'MAN': 10, 'FATHER': 38, 'HIM': 38, 'HE': 157}
# percentage for label as male: 0.00823393873679
# For female:  28.0 {'MOTHER': 28}
# percentage for label as female: 0.000948766603416
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_11304.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# total number of words:  30253
# For male:  150.0 {'SIR': 2, 'MAN': 3, 'FATHER': 4, 'HIM': 11, 'HE': 130}
# percentage for label as male: 0.00495818596503
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1240.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# total number of words:  28655
# For male:  216.0 {'MAN': 11, 'HIM': 45, 'HE': 160}
# percentage for label as male: 0.00753795149189
# For female:  2.0 {'SISTER': 2}
# percentage for label as female: 6.97958471471e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1256.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# total number of words:  27076
# For male:  36.0 {'MASTER': 6, 'HIM': 5, 'HE': 25}
# percentage for label as male: 0.0013295907815
# For female:  1.0 {'SHE': 1}
# percentage for label as female: 3.6933077264e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1272.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# Completed reading rows32000
# Completed reading rows33000
# Completed reading rows34000
# total number of words:  34390
# For male:  308.0 {'COUNT': 4, 'HIM': 6, 'HE': 298}
# percentage for label as male: 0.00895609188718
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1284.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29865
# For male:  62.0 {'HIM': 2, 'MAN': 1, 'CHAIRMAN': 34, 'ACTOR': 8, 'HE': 17}
# percentage for label as male: 0.00207600870584
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1342.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29431
# For male:  4.0 {'BROTHER': 4}
# percentage for label as male: 0.000135911114131
# For female:  4.0 {'SISTER': 4}
# percentage for label as female: 0.000135911114131
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1345.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29100
# For male:  3.0 {'COUNT': 3}
# percentage for label as male: 0.000103092783505
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1382.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# Completed reading rows32000
# Completed reading rows33000
# total number of words:  33205
# For male:  56.0 {'HE': 56}
# percentage for label as male: 0.00168649299804
# For female:  127.0 {'WOMAN': 106, 'SHE': 15, 'MOTHER': 6}
# percentage for label as female: 0.00382472519199
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1508.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# total number of words:  31677
# For male:  49.0 {'GIANT': 8, 'HIM': 2, 'HE': 39}
# percentage for label as male: 0.00154686365502
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1541.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# total number of words:  21768
# For male:  14.0 {'HUSBAND': 6, 'HE': 8}
# percentage for label as male: 0.000643145902242
# For female:  31.0 {'WOMAN': 4, 'SHE': 27}
# percentage for label as female: 0.00142410878354
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1629.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# total number of words:  30940
# For male:  82.0 {'COUNT': 6, 'SIR': 2, 'HIM': 11, 'HE': 63}
# percentage for label as male: 0.00265029088559
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_1631.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29933
# For male:  413.0 {'RAM': 8, 'HOST': 3, 'POLICEMAN': 12, 'HIM': 80, 'HE': 310}
# percentage for label as male: 0.013797481041
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_380.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# total number of words:  31911
# For male:  21.0 {'COUNT': 2, 'DOG': 3, 'BROTHER': 4, 'HE': 12}
# percentage for label as male: 0.000658080285795
# For female:  76.0 {'WOMAN': 28, 'SHE': 8, 'MOTHER': 40}
# percentage for label as female: 0.00238162389145
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_381.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# total number of words:  30225
# For male:  49.0 {'COUNT': 3, 'HE': 40, 'HIM': 2, 'BROTHER': 4}
# percentage for label as male: 0.0016211745244
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_547.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# total number of words:  28329
# For male:  110.0 {'COUNT': 6, 'HIM': 14, 'HE': 90}
# percentage for label as male: 0.00388294680363
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_595.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# total number of words:  25482
# For male:  42.0 {'COUNT': 2, 'DUKE': 1, 'DOG': 3, 'HE': 27, 'HIM': 4, 'MAN': 5}
# percentage for label as male: 0.00164822227455
# For female:  41.0 {'WIFE': 1, 'DAUGHTER': 6, 'SHE': 14, 'MOTHER': 20}
# percentage for label as female: 0.00160897888706
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_608.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# total number of words:  31048
# For male:  24.0 {'COUNT': 5, 'MASTER': 4, 'HE': 15}
# percentage for label as male: 0.000772996650348
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_6551.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# total number of words:  27442
# For male:  73.0 {'FATHER': 6, 'HE': 67}
# percentage for label as male: 0.00266015596531
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_669.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# Completed reading rows32000
# Completed reading rows33000
# Completed reading rows34000
# Completed reading rows35000
# total number of words:  35048
# For male:  13.0 {'HE': 13}
# percentage for label as male: 0.000370919881306
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_7058.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# total number of words:  30531
# For male:  204.0 {'HIM': 21, 'HE': 183}
# percentage for label as male: 0.00668173332023
# For female:  15.0 {'SHE': 15}
# percentage for label as female: 0.000491303920605
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_85.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29600
# For male:  51.0 {'BROTHER': 4, 'DUKE': 3, 'HIM': 2, 'KING': 3, 'HE': 39}
# percentage for label as male: 0.00172297297297
# For female:  4.0 {'SHE': 4}
# percentage for label as female: 0.000135135135135
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_8820.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# total number of words:  26695
# For male:  59.0 {'COUNT': 2, 'SIR': 27, 'HIM': 3, 'HE': 27}
# percentage for label as male: 0.0022101517138
# For female:  2.0 {'SHE': 2}
# percentage for label as female: 7.49203970781e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_9222.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# total number of words:  26945
# For male:  196.0 {'BROTHER': 6, 'COUNT': 3, 'HIM': 9, 'HE': 178}
# percentage for label as male: 0.00727407682316
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_05_9264.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# total number of words:  29841
# For male:  25.0 {'COUNT': 4, 'HIM': 2, 'HE': 19}
# percentage for label as male: 0.000837773533059
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_102.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# total number of words:  17431
# For male:  1.0 {'HE': 1}
# percentage for label as male: 5.73690551317e-05
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_134.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# total number of words:  28514
# For male:  25.0 {'HIM': 5, 'HE': 20}
# percentage for label as male: 0.000876762292207
# For female:  0.0 {}
# percentage for label as female: 0.0
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_157.csv
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_278.csv
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_313.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# total number of words:  25063
# For male:  262.0 {'GENTLEMEN': 36, 'COUNT': 1, 'MAN': 1, 'HIM': 33, 'HE': 191}
# percentage for label as male: 0.0104536567849
# For female:  30.0 {'LADIES': 24, 'SHE': 6}
# percentage for label as female: 0.00119698360132
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_484.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# total number of words:  26692
# For male:  67.0 {'HE': 67}
# percentage for label as male: 0.00251011539038
# For female:  3.0 {'SHE': 3}
# percentage for label as female: 0.000112393226435
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_5247.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# total number of words:  12387
# For male:  67.0 {'MANKIND': 2, 'MAN': 8, 'GENTLEMAN': 6, 'HIM': 6, 'HE': 45}
# percentage for label as male: 0.00540889642367
# For female:  20.0 {'WOMAN': 8, 'SHE': 12}
# percentage for label as female: 0.00161459594736
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_531.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# total number of words:  15152
# For male:  39.0 {'HIM': 3, 'HE': 36}
# percentage for label as male: 0.00257391763464
# For female:  18.0 {'SHE': 18}
# percentage for label as female: 0.00118796198522
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_562.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# Completed reading rows32000
# Completed reading rows33000
# total number of words:  33627
# For male:  29.0 {'HOST': 3, 'HIM': 3, 'HE': 23}
# percentage for label as male: 0.000862402236298
# For female:  2.0 {'DAM': 2}
# percentage for label as female: 5.94760162964e-05
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_593.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# total number of words:  17332
# For male:  14.0 {'UNCLE': 4, 'SON': 5, 'HE': 2, 'MAN': 3}
# percentage for label as male: 0.000807754442649
# For female:  30.0 {'WOMAN': 6, 'DAUGHTER': 10, 'AUNT': 2, 'SHE': 2, 'MOTHER': 8, 'LADY': 2}
# percentage for label as female: 0.00173090237711
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_618.csv
# Completed reading rows1000
# Completed reading rows2000
# Completed reading rows3000
# Completed reading rows4000
# Completed reading rows5000
# Completed reading rows6000
# Completed reading rows7000
# Completed reading rows8000
# Completed reading rows9000
# Completed reading rows10000
# Completed reading rows11000
# Completed reading rows12000
# Completed reading rows13000
# Completed reading rows14000
# Completed reading rows15000
# Completed reading rows16000
# Completed reading rows17000
# Completed reading rows18000
# Completed reading rows19000
# Completed reading rows20000
# Completed reading rows21000
# Completed reading rows22000
# Completed reading rows23000
# Completed reading rows24000
# Completed reading rows25000
# Completed reading rows26000
# Completed reading rows27000
# Completed reading rows28000
# Completed reading rows29000
# Completed reading rows30000
# Completed reading rows31000
# total number of words:  31501
# For male:  202.0 {'HIM': 23, 'HE': 179}
# percentage for label as male: 0.00641249484143
# For female:  10.0 {'SHE': 4, 'DOE': 6}
# percentage for label as female: 0.000317450239675
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# /Users/richadeshmukh/Desktop/TEMP/11_OralImplicitBias-master/preprocessing/audio/inputs/2006/ABA/2006_06_969.csv
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
#
# Counter1 is 1
